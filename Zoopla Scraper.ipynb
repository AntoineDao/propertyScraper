# %%
import requests

# %%
link = "https://www.zoopla.co.uk/to-rent/property/edinburgh-city-centre/?beds_min=2&price_frequency=per_month&price_max=1000&q=Edinburgh%20City%20Centre%2C%20Edinburgh&results_sort=newest_listings&search_source=home"
page = requests.get(link)

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(page.content, 'html.parser')

# %%
results_id = "l-searchResults"

results = soup.find_all("li", {"class": "clearfix"})

base_link = "https://www.zoopla.co.uk/to-rent/details/"

# results_link = [base_link + result["data-listing-id"] for result in results]

results_links = []

for result in results:
    try:
        results_links.append(base_link + result["data-listing-id"])
    except:
        pass
results_links
# Out:
# ['https://www.zoopla.co.uk/to-rent/details/46653584',
#  'https://www.zoopla.co.uk/to-rent/details/46633223',
#  'https://www.zoopla.co.uk/to-rent/details/46632582',
#  'https://www.zoopla.co.uk/to-rent/details/46567655',
#  'https://www.zoopla.co.uk/to-rent/details/46552461',
#  'https://www.zoopla.co.uk/to-rent/details/46552476',
#  'https://www.zoopla.co.uk/to-rent/details/46507763',
#  'https://www.zoopla.co.uk/to-rent/details/46477451',
#  'https://www.zoopla.co.uk/to-rent/details/46425422',
#  'https://www.zoopla.co.uk/to-rent/details/46335077',
#  'https://www.zoopla.co.uk/to-rent/details/46285314',
#  'https://www.zoopla.co.uk/to-rent/details/46278745',
#  'https://www.zoopla.co.uk/to-rent/details/46209641',
#  'https://www.zoopla.co.uk/to-rent/details/46138244']

# %%
individual_link = results_links[0]

individual_page = requests.get(individual_link)
individual_soup = BeautifulSoup(individual_page.content, "html.parser")

# %%
individual_soup.find("h3", string="Property features").next_sibling.next_sibling
# Out:
# <ul>
# <li>Central Heating</li>
# <li>Shower</li>
# <li>Double Glazing</li>
# <li>No Smoking</li>
# <li>No pets</li>
# <li>En-suite</li>
# </ul>

# %%
import re
re.sub("\s", "", individual_soup.find("div", {"class":"listing-details-price"}).getText()).split("pcm")[0].split("£")[1]
# Out:
# '850'

# %%
individual_soup.find("h2", {"class": "listing-details-h1"}).getText()
# Out:
# '2 bed flat to rent'

# %%
for link in results_links:

    individual_page = requests.get(link)
    individual_soup = BeautifulSoup(individual_page.content, "html.parser")

    print("ADDRESS DETAILS")
    print(link)
    print(individual_soup.find("h2", {"itemprop": "streetAddress"}).getText())
    print(individual_soup.find("meta", {"itemprop": "addressLocality"})["content"])
    print(individual_soup.find("meta", {"itemprop": "latitude"})["content"])
    print(individual_soup.find("meta", {"itemprop": "longitude"})["content"])
    print("~~~~~~~~~~~~~~~~~~~~~~")
# Out:
# ADDRESS DETAILS
# https://www.zoopla.co.uk/to-rent/details/46633223
# Dicksonfield, Leith Walk, Edinburgh EH7
# Edinburgh
# 55.961468
# -3.179535
# ~~~~~~~~~~~~~~~~~~~~~~
# ADDRESS DETAILS
# https://www.zoopla.co.uk/to-rent/details/46632582
# Grindlay Street, Grassmarket, Edinburgh EH3
# Edinburgh
# 55.94669
# -3.203393
# ~~~~~~~~~~~~~~~~~~~~~~
# ADDRESS DETAILS
# https://www.zoopla.co.uk/to-rent/details/46567655
# Parsons Green Terrace, Edinburgh EH8
# 20 1f2 Parsons Green Terrace
# 55.954983
# -3.152976
# ~~~~~~~~~~~~~~~~~~~~~~
# ADDRESS DETAILS
# https://www.zoopla.co.uk/to-rent/details/46552461
# Easter Road, Edinburgh EH7
# Edinburgh
# 55.96188
# -3.171346
# ~~~~~~~~~~~~~~~~~~~~~~
# ADDRESS DETAILS
# https://www.zoopla.co.uk/to-rent/details/46552476
# William Street, Edinburgh EH3
# Edinburgh
# 55.948612
# -3.213765
# ~~~~~~~~~~~~~~~~~~~~~~
# ADDRESS DETAILS
# https://www.zoopla.co.uk/to-rent/details/46507763
# Cornwallis Place, Bellevue, Edinburgh EH3
# Edinburgh
# 55.96108
# -3.194789
# ~~~~~~~~~~~~~~~~~~~~~~
# ADDRESS DETAILS
# https://www.zoopla.co.uk/to-rent/details/46507715
# Albert Street, Leith, Edinburgh EH7
# Edinburgh
# 55.962753
# -3.177908
# ~~~~~~~~~~~~~~~~~~~~~~
# ADDRESS DETAILS
# https://www.zoopla.co.uk/to-rent/details/46477451
# St Marys Street, Central, Edinburgh EH1
# Edinburgh
# 55.95037
# -3.183618
# ~~~~~~~~~~~~~~~~~~~~~~
# ADDRESS DETAILS
# https://www.zoopla.co.uk/to-rent/details/46425422
# Moray Park Terrace, Meadowbank, Edinburgh EH7
# EH7 5TN
# 55.95819
# -3.163338
# ~~~~~~~~~~~~~~~~~~~~~~
# ADDRESS DETAILS
# https://www.zoopla.co.uk/to-rent/details/46335077
# Royal Park Terrace, Abbeyhill, Edinburgh EH8
# Edinburgh
# 55.95484
# -3.158369
# ~~~~~~~~~~~~~~~~~~~~~~
# ADDRESS DETAILS
# https://www.zoopla.co.uk/to-rent/details/46285314
# Leith Street, New Town, Edinburgh EH1
# Edinburgh
# 55.95405
# -3.187638
# ~~~~~~~~~~~~~~~~~~~~~~
# ADDRESS DETAILS
# https://www.zoopla.co.uk/to-rent/details/46278745
# Canongate, Edinburgh EH8
# Edinburgh
# 55.95061
# -3.183545
# ~~~~~~~~~~~~~~~~~~~~~~
# ADDRESS DETAILS
# https://www.zoopla.co.uk/to-rent/details/46209641
# Brunswick Road, Edinburgh EH7
# EH7 5PD
# 55.961002
# -3.172104
# ~~~~~~~~~~~~~~~~~~~~~~
# ADDRESS DETAILS
# https://www.zoopla.co.uk/to-rent/details/46138244
# Portobello Road, Edinburgh EH8
# EH8 7AY
# 55.955257
# -3.148595
# ~~~~~~~~~~~~~~~~~~~~~~
# ADDRESS DETAILS
# https://www.zoopla.co.uk/to-rent/details/46399192
# Harrismith Place, Edinburgh EH7
# EH7 5PA
# 55.961277
# -3.169486
# ~~~~~~~~~~~~~~~~~~~~~~

# %%
re.sub("\s", " ", individual_soup.find("div", {"itemprop": "description"}).getText())
# Out:
# ' Ref: 88T: Harrismith placeBright 2 bedroom flat located in Harrismith Place, a quiet residential street just off Albion Road and just moments from Easter Road. The local area is host to a number of shops, parks and restaurants and there are excellent bus links nearby. Princes Street is only a twenty minute walk and nearby amenities includes Meadowbank Shopping Centre, a Tesco supermarket and Leith Links public park.The 1st floor property is part of a modern development and is available furnished, comprising:~Bright and airy lounge with large bay window, small diner and laminate flooring~Modern kitchen with selection of appliances, good storage and tiled splashback~Master double bedroom with carpeted flooring and built-in sliding mirrored wardrobe~Second double bedroom with carpeted flooring and built-in sliding mirrored wardrobe~Bathroom with three-piece suite including electric shower over bath~Entrance hallway providing access to all rooms~Private resident parking~Gas heating~Double glazing~Secure entry~Sorry, no pets~Total floor area = 63m²~Council tax: Band D~EPC rating: C~Landlord registration: 93554/230/24250~Please note this is a “Let Only” property and the Landlord will manage the property themselvesAvailable: 6th February 2018Rent: £850pcmDeposit: £850Please note the photographs shown within this advertisement may have been taken whilst a tenancy was active in the property and as a result you should not rely on these as an accurate representation of furnishings and items included in the agreement. A full list of which items included in the property are available upon request from our officeProperty Reference:88T edi hp '

# %%
from dateutil.parser import parse
import re

for link in results_links:

    individual_page = requests.get(link)
    individual_soup = BeautifulSoup(individual_page.content, "html.parser")

    info = individual_soup.find("h3", string="Property info").next_sibling.next_sibling.find_all("li")#.getText()
#     for element in info:
#         element = element.getText()
#         if "Available from" in element:
#             date_available = re.sub("Available from ", "", element)
#             print(parse(date_available))
    print(link)
    print(info)
# Out:
# https://www.zoopla.co.uk/to-rent/details/46653584
# [<li>Available immediately</li>, <li>Part furnished</li>]
# https://www.zoopla.co.uk/to-rent/details/46633223
# [<li>Available immediately</li>, <li>Unfurnished</li>]
# https://www.zoopla.co.uk/to-rent/details/46632582
# [<li>Available from 19th Mar 2018</li>, <li>Furnished</li>]
# https://www.zoopla.co.uk/to-rent/details/46567655
# [<li>Available immediately</li>, <li>Furnished</li>]
# https://www.zoopla.co.uk/to-rent/details/46552476
# [<li>Available from 27th Mar 2018</li>, <li>Furnished</li>]
# https://www.zoopla.co.uk/to-rent/details/46552461
# [<li>Available immediately</li>, <li>Furnished</li>]
# https://www.zoopla.co.uk/to-rent/details/46507763
# [<li>Available from 10th May 2018</li>, <li>Furnished</li>]
# https://www.zoopla.co.uk/to-rent/details/46507715
# [<li>Available from 19th Aug 2018</li>, <li>Furnished</li>]
# https://www.zoopla.co.uk/to-rent/details/46477451
# [<li>Available from 23rd Jul 2018</li>, <li>Furnished</li>]
# https://www.zoopla.co.uk/to-rent/details/46425422
# [<li>
# <a data-ga-action="epc_graph" data-ga-category="Listing attachments" data-ga-label="/tracking/to-rent/details/46425422" data-taxonomy='{"listings_category":"residential","listing_tools":"epc_graph","section":"to-rent","activity":"listing_details"}' href="https://lc.zoocdn.com/b8d4231b0372d22e27c27f7d4583c44088bcbfcb.png" onclick="popup = window.open(this.href,'name','left=200,top=150,height=550,width=700,toolbar=no,directories=no,status=no,menubar=no,scrollbars=yes,resizable=yes,titlebar=no');return false;displayPopup(popup);" rel="nofollow"><span>Energy Performance Certificate (EPC) graph</span></a>
# </li>, <li>Available immediately</li>, <li>Furnished</li>]
# https://www.zoopla.co.uk/to-rent/details/46335077
# [<li>Available immediately</li>, <li>Furnished</li>]
# https://www.zoopla.co.uk/to-rent/details/46285314
# [<li>Available from  5th Mar 2018</li>, <li>Unfurnished</li>]
# https://www.zoopla.co.uk/to-rent/details/46278745
# [<li>Available immediately</li>, <li>Furnished</li>]
# https://www.zoopla.co.uk/to-rent/details/46209641
# [<li>Available immediately</li>, <li>Furnished</li>]
# https://www.zoopla.co.uk/to-rent/details/46138244
# [<li>
# <a data-ga-action="epc_report" data-ga-category="Listing attachments" data-ga-label="/tracking/to-rent/details/46138244" data-taxonomy='{"listings_category":"residential","listing_tools":"epc_report","section":"to-rent","activity":"listing_details"}' href="https://lc.zoocdn.com/444eb57ac6c70ebf98bb1f3d2b38cdb9825a7ada.pdf" onclick="popup = window.open(this.href,'name','left=200,top=150,height=550,width=700,toolbar=no,directories=no,status=no,menubar=no,scrollbars=yes,resizable=yes,titlebar=no');return false;displayPopup(popup);" rel="nofollow"><span>Energy Performance Certificate (EPC) report</span></a>
# </li>, <li>Available immediately</li>, <li>Unfurnished</li>]
# https://www.zoopla.co.uk/to-rent/details/46399192
# [<li>Available immediately</li>, <li>Furnished</li>]

# %%
monthly_costs = ["Rent", "Insurance", "Energy", "Water", "Council Tax"]

for cost in monthly_costs:
    datum = individual_soup.find("button", {"data-rc-name": cost}).find("span", {"rc-option-btn-price"}).getText()
    print(cost + ": " + datum)
# Out:
# Rent: £850
# Insurance: £19
# Energy: £79
# Water: £53
# Council Tax: £120

# %%
for link in results_links:
    print(link)
    individual_page = requests.get(link)
    individual_soup = BeautifulSoup(individual_page.content, "html.parser")
    try:
        print(individual_soup.find("h3", string="Property features").next_sibling.next_sibling)
    except:
        pass
# Out:
# https://www.zoopla.co.uk/to-rent/details/46633223
# <ul>
# <li>Central Heating</li>
# <li>Shower</li>
# <li>Double Glazing</li>
# <li>No Smoking</li>
# <li>No pets</li>
# <li>En-suite</li>
# </ul>
# https://www.zoopla.co.uk/to-rent/details/46632582
# <ul>
# <li>Dishwasher</li>
# <li>Central Heating</li>
# <li>Shower</li>
# <li>Double Glazing</li>
# <li>No Smoking</li>
# <li>No pets</li>
# </ul>
# https://www.zoopla.co.uk/to-rent/details/46567655
# <ul>
# <li>Washing Machine</li>
# <li>Gas Hob</li>
# <li>Shower</li>
# <li>Double Glazing</li>
# </ul>
# https://www.zoopla.co.uk/to-rent/details/46552476
# https://www.zoopla.co.uk/to-rent/details/46552461
# https://www.zoopla.co.uk/to-rent/details/46507763
# <ul>
# <li>No Smoking</li>
# <li>No pets</li>
# </ul>
# https://www.zoopla.co.uk/to-rent/details/46507715
# <ul>
# <li>Fridge Freezer</li>
# <li>Central Heating</li>
# <li>Shower</li>
# <li>No Smoking</li>
# <li>No pets</li>
# <li>Secure Entry</li>
# </ul>
# https://www.zoopla.co.uk/to-rent/details/46477451
# <ul>
# <li>No Smoking</li>
# <li>No pets</li>
# </ul>
# https://www.zoopla.co.uk/to-rent/details/46425422
# <ul>
# <li>Fridge Freezer</li>
# <li>Washer Dryer</li>
# <li>Private Parking</li>
# <li>Shower</li>
# <li>Smoke Detector</li>
# <li>Double Glazing</li>
# <li>Laminate Flooring</li>
# <li>All White Goods</li>
# <li>No Smoking</li>
# <li>No pets</li>
# <li>No DSS</li>
# <li>1st Floor</li>
# <li>No Children</li>
# <li>Secure Entry</li>
# <li>EPC Rating - C</li>
# <li>Council Tax Band - D</li>
# <li>Gas CH</li>
# <li>Fitted Kitchen</li>
# </ul>
# https://www.zoopla.co.uk/to-rent/details/46335077
# <ul>
# <li>No Smoking</li>
# <li>No pets</li>
# <li>On Street Parking</li>
# </ul>
# https://www.zoopla.co.uk/to-rent/details/46285314
# https://www.zoopla.co.uk/to-rent/details/46278745
# <ul>
# <li>Central Heating</li>
# </ul>
# https://www.zoopla.co.uk/to-rent/details/46209641
# <ul>
# <li>Fridge Freezer</li>
# <li>Washing Machine</li>
# <li>Shower</li>
# <li>All White Goods</li>
# <li>No pets</li>
# <li>No DSS</li>
# <li>Permit Parking Available</li>
# <li>2nd Floor</li>
# <li>Public Transport Links</li>
# <li>Secure Entry</li>
# <li>EPC Rating - C</li>
# <li>Council Tax Band - C</li>
# <li>Bath</li>
# </ul>
# https://www.zoopla.co.uk/to-rent/details/46138244
# <ul>
# <li>Fridge Freezer</li>
# <li>Washing Machine</li>
# <li>Electric Hob</li>
# <li>Electric Oven</li>
# <li>Central Heating</li>
# <li>Shared Garden</li>
# <li>Parking</li>
# <li>Shower</li>
# <li>Smoke Detector</li>
# <li>Double Glazing</li>
# <li>Carpet Flooring</li>
# <li>Laminate Flooring</li>
# <li>All White Goods</li>
# <li>No Smoking</li>
# <li>No pets</li>
# <li>No DSS</li>
# <li>2nd Floor</li>
# <li>Children Welcome</li>
# <li>Not hmo</li>
# <li>Public Transport Links</li>
# <li>Secure Entry</li>
# <li>EPC Rating - C</li>
# <li>Council Tax Band - B</li>
# <li>Gas CH</li>
# <li>Bath</li>
# <li>Fitted Kitchen</li>
# <li>On Street Parking</li>
# </ul>
# https://www.zoopla.co.uk/to-rent/details/46399192
# <ul>
# <li>Fridge Freezer</li>
# <li>Washing Machine</li>
# <li>Shower</li>
# <li>Double Glazing</li>
# <li>Laminate Flooring</li>
# <li>All White Goods</li>
# <li>No pets</li>
# <li>No DSS</li>
# <li>1st Floor</li>
# <li>Public Transport Links</li>
# <li>Secure Entry</li>
# <li>EPC Rating - C</li>
# <li>Council Tax Band - D</li>
# <li>Bath</li>
# </ul>

# %%
from propertyscraper.address import Address

addr = Address.from_zoopla(individual_soup)

addr.to_json()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-ff964e7c3443> in <module>()
#       1 from propertyscraper.address import Address
#       2
# ----> 3 addr = Address.from_zoopla(individual_soup)
#       4
#       5 addr.to_json()
#
# NameError: name 'individual_soup' is not defined

# %%
from propertyscraper.key_info import KeyInfo

info = KeyInfo.from_zoopla(individual_soup)
info.to_json()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-c263049d93ed> in <module>()
#       1 from propertyscraper.key_info import KeyInfo
#       2
# ----> 3 info = KeyInfo.from_zoopla(individual_soup)
#       4 info.to_json()
#
# NameError: name 'individual_soup' is not defined

# %%
from propertyscraper.accomodation import rentedAccomodation

id = "46425422"

accom = rentedAccomodation.from_zoopla(id)
accom.to_json()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-6-614ff2554f54> in <module>()
# ----> 1 from propertyscraper.accomodation import rentedAccomodation
#       2
#       3 id = "46425422"
#       4
#       5 accom = rentedAccomodation.from_zoopla(id)
#
# ImportError: cannot import name 'rentedAccomodation'

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from propertyscraper.search import RentedSearch
link ="https://www.zoopla.co.uk/to-rent/property/edinburgh-city-centre/?beds_min=2&price_frequency=per_month&price_max=1000&q=Edinburgh%20City%20Centre%2C%20Edinburgh&results_sort=newest_listings&search_source=home"
search = RentedSearch.from_zoopla(link)
[item.to_json() for item in search.data]
# Out:
# [{'address': {'area': None,
#    'city': 'Hillside',
#    'latitude': 55.959747,
#    'longitude': -3.178394,
#    'postcode': 'EH7',
#    'street': 'West Montgomery Place',
#    'tags': []},
#   'description': ' Deposit £300 - Immaculately presented two bedroom apartment, situated just a few minutes` walk from the City centre and in easy reach of an abundance of local shops, cafes and bars, available, fully furnished. This first floor apartment is in great decorative order throughout and would make an ideal home for a single professional or couple. The property comprises bright and airy living room with feature cornices and fireplace, fully equipped, modern kitchen, one double bedroom and one single bedroom/study and a bathroom with shower over bath. The property also benefits from a secure door entry system, gas central heating and a shared garden to the back. Landlord Registration number: 465018/230/26281 ',
#   'href': 'https://www.zoopla.co.uk/to-rent/details/46725697',
#   'key_info': {'council_tax': None,
#    'date_available': '25/02/2018',
#    'deposit': None,
#    'epc': None,
#    'furnishing': 'furnished',
#    'letting_type': None,
#    'rent': 950.0,
#    'running_costs': {'council_tax': None,
#     'energy': 79.0,
#     'insurrance': 19.0,
#     'water': 53.0}},
#   'source': 'zoopla',
#   'tags': ['Central Heating', 'Council Tax Band - B', 'Fitted Kitchen'],
#   'title': '2 bed flat to rent'},
#  {'address': {'area': 'New Town',
#    'city': 'Edinburgh',
#    'latitude': 55.9588,
#    'longitude': -3.18993,
#    'postcode': 'EH1',
#    'street': 'Broughton Street',
#    'tags': []},
#   'description': ' Large sunny flat comprising hallway with storage, lounge with bay windows and window seats, 2 double bedrooms, good sized dining kitchen, bathroom with bath and shower. Seperate WC. Landlord registration number: 48148/230/26360Deposit: £1,050 ',
#   'href': 'https://www.zoopla.co.uk/to-rent/details/46723310',
#   'key_info': {'council_tax': None,
#    'date_available': '21/03/2018',
#    'deposit': None,
#    'epc': None,
#    'furnishing': 'part furnished',
#    'letting_type': None,
#    'rent': 950.0,
#    'running_costs': {'council_tax': 196.0,
#     'energy': 79.0,
#     'insurrance': 32.0,
#     'water': 53.0}},
#   'source': 'zoopla',
#   'tags': ['Washing Machine', 'Dishwasher', 'Double Glazing'],
#   'title': '2 bed flat to rent'},
#  {'address': {'area': None,
#    'city': 'Edinburgh',
#    'latitude': 55.96218,
#    'longitude': -3.179237,
#    'postcode': 'EH7',
#    'street': 'Albert Place',
#    'tags': []},
#   'description': ' Ref: 1946L: Albert placeDesirable 2 bedroom main door property located on Albert Place, forming part of Leith Walk. Bus links are readily available from the doorstep with services to the City Centre, West End, Leith and many other areas of Edinburgh. Princes Street is a fifteen minute walk and there are excellent local amenities on offer including shops, bars and restaurants just moments away. The property’s central location makes it ideal for a professional couple or for students.The 1st floor property features high ceilings, neutral décor and is part-furnished. It comprises:~Bright and contemporary lounge with hardwood flooring, small dining area and lots of natural light~Modern kitchen with selection of appliances, excellent storage and tiled splashback~Very bright double bedroom with laminate flooring and storage cupboard~Second, internal double bedroom (without bed) ideal as spare/child’s room~Tiled bathroom with stylish suite including separate shower/bath~Entrance hallway providing access to all rooms~Zone permit parking nearby~Electric heating~Double glazing~Main door entry~Sorry, no pets~Council tax: Band C~EPC rating: F~Landlord registration: 461255/230/10311Available: NowRent: £895pcmDeposit: £895Please note the photographs shown within this advertisement may have been taken whilst a tenancy was active in the property and as a result you should not rely only on these as an accurate representation of furnishings and items included in the agreement. A full list of which items are included in the property is available upon request from our office, based on a previous tenancy. A viewing is therefore required in order to ensure you have an accurate understanding and knowledge of the condition and contents of the property.Property Reference:1946L edi ap ',
#   'href': 'https://www.zoopla.co.uk/to-rent/details/46653584',
#   'key_info': {'council_tax': None,
#    'date_available': '25/02/2018',
#    'deposit': None,
#    'epc': None,
#    'furnishing': 'part furnished',
#    'letting_type': None,
#    'rent': 895.0,
#    'running_costs': {'council_tax': 107.0,
#     'energy': 79.0,
#     'insurrance': 19.0,
#     'water': 53.0}},
#   'source': 'zoopla',
#   'tags': ['Fridge Freezer',
#    'Washing Machine',
#    'Electric Heating',
#    'Shower',
#    'Double Glazing',
#    'No DSS',
#    'Permit Parking Available',
#    '1st Floor',
#    'Main Door',
#    'Public Transport Links',
#    'EPC Rating - F',
#    'Council Tax Band - C',
#    'Bath'],
#   'title': '2 bed flat to rent'},
#  {'address': {'area': 'Grassmarket',
#    'city': 'Edinburgh',
#    'latitude': 55.94669,
#    'longitude': -3.203393,
#    'postcode': 'EH3',
#    'street': 'Grindlay Street',
#    'tags': []},
#   'description': ' Available March 2018The property will painted throughout prior to the start of the new tenancy.LocationThis central 2 bedroom flat is located in an excellent position close to Lothian Road, Princes Street and the Grassmarket. Grindlay Street is a side street with limited traffic but has many restaurants, bars and cafes in the vicinity.PropertyThe property comprises of hallway with wooden flooring and good storage, spacious living room with decorative fireplace and cornicing, 2 double bedrooms, modern kitchen with window seat and dining table, modern bathroom and separate toilet. The property has double glazed sash and case windows throughout, gas central heating, fresh decor and wooden flooring in the living areas.Sorry no pets, students or DSS. Council tax band C. Deposit £1500 EPC rating: C. Landlord Registration Number: 416832/230/16371. ',
#   'href': 'https://www.zoopla.co.uk/to-rent/details/46632582',
#   'key_info': {'council_tax': None,
#    'date_available': '19/03/2018',
#    'deposit': None,
#    'epc': None,
#    'furnishing': 'furnished',
#    'letting_type': None,
#    'rent': 1000.0,
#    'running_costs': {'council_tax': 107.0,
#     'energy': 79.0,
#     'insurrance': 19.0,
#     'water': 53.0}},
#   'source': 'zoopla',
#   'tags': ['Dishwasher',
#    'Central Heating',
#    'Shower',
#    'Double Glazing',
#    'No Smoking',
#    'No pets'],
#   'title': '2 bed flat to rent'},
#  {'address': {'area': None,
#    'city': 'Edinburgh',
#    'latitude': 55.954983,
#    'longitude': -3.152976,
#    'postcode': 'EH8',
#    'street': 'Parsons Green Terrace',
#    'tags': []},
#   'description': " An immaculate stairwell leads you to a very well kept and comfortably furnished 2 bed first floor flat. Despite overlooking London Road near Meadowbank Stadium, the double glazing keeps the street noise at bay allowing the occupant to relax in their surroundings and to enjoy the wonderful view. Nearby Meadowbank retail park has a Sainsbury's supermarket. Landlord registration number 38844/230/25020.Some of the items shown in the photos belong to the current occupant and will not be included when the property is let. Please ask for confirmation during viewings. ",
#   'href': 'https://www.zoopla.co.uk/to-rent/details/46567655',
#   'key_info': {'council_tax': None,
#    'date_available': '25/02/2018',
#    'deposit': None,
#    'epc': None,
#    'furnishing': 'furnished',
#    'letting_type': None,
#    'rent': 825.0,
#    'running_costs': {'council_tax': None,
#     'energy': 79.0,
#     'insurrance': 15.0,
#     'water': 53.0}},
#   'source': 'zoopla',
#   'tags': ['Washing Machine', 'Gas Hob', 'Shower', 'Double Glazing'],
#   'title': '2 bed flat to rent'},
#  {'address': {'area': None,
#    'city': 'Edinburgh',
#    'latitude': 55.948612,
#    'longitude': -3.213765,
#    'postcode': 'EH3',
#    'street': 'William Street',
#    'tags': []},
#   'description': ' A delightful 2 bed first floor flat situated in a much sought after location within the West End Village.The spacious and pleasant accommodation is on the 1st floor, and internally comprises 2 double bedrooms, bright south facing kitchen with modern appliances, separate WC and shower room with power shower and a delightiful tile surround, plenty hall storage and a large, bright living room with traditional features and Edinburgh press cupboard.This property would idally suit two individual professionals or phd students, or a professional couple.Further benefits are GCH and combi boiler.The West End offers excellent facilities with a wide range of quality shopping within easy walking distance of the property and a good choice of fashionable restaurants, bars and bistros, leisure and recreational facilities and all the usual amenities.There is excellent schooling at both primary and secondary levels within the public and private sector. In addition the property is well placed for the financial and commercial district of the City. Haymarket Station is nearby with frequent services operating to Glasgow and the main Scottish towns and Cities and there is good access via Corstorphine Road to the City Bypass, airport and motorway routes north and west.Deposit: £995 ',
#   'href': 'https://www.zoopla.co.uk/to-rent/details/46552476',
#   'key_info': {'council_tax': None,
#    'date_available': '27/03/2018',
#    'deposit': None,
#    'epc': None,
#    'furnishing': 'furnished',
#    'letting_type': None,
#    'rent': 995.0,
#    'running_costs': {'council_tax': None,
#     'energy': 79.0,
#     'insurrance': 28.0,
#     'water': 53.0}},
#   'source': 'zoopla',
#   'tags': None,
#   'title': '2 bed flat to rent'},
#  {'address': {'area': 'Bellevue',
#    'city': 'Edinburgh',
#    'latitude': 55.96108,
#    'longitude': -3.194789,
#    'postcode': 'EH3',
#    'street': 'Cornwallis Place',
#    'tags': []},
#   'description': ' This property is offered fully furnished and comprises of- Lounge- Kitchen- Double bedrooms- Family bathroom- En-suite shower roomFeatures -- Original features and cornicing- Storage options throughout property- GCHSituated to the north of the city centre, Bellevue is an appealing location for many types of residents, particularly young professionals. The area is highly attractive for the multitude of shops, bars and restaurants nearby as well the popular Omni Centre being within walking distance offering a cinema as well as many eateries. The area also benefits from superb transport links in the area with Edinburgh Waverley rail station within close reach as well as easy access to the tram service in the city which offers direct routes to Edinburgh Airport. Additionally, regular bus services are also in operation making it easy to get around the city.Managed by ARLA registered agent Grant Property with a 24-hour emergency repairs service.Landlord Registration Number: 95293/230/17440.Deposit: £1,100 ',
#   'href': 'https://www.zoopla.co.uk/to-rent/details/46507763',
#   'key_info': {'council_tax': None,
#    'date_available': '10/05/2018',
#    'deposit': None,
#    'epc': None,
#    'furnishing': 'furnished',
#    'letting_type': None,
#    'rent': 910.0,
#    'running_costs': {'council_tax': None,
#     'energy': 79.0,
#     'insurrance': 31.0,
#     'water': 53.0}},
#   'source': 'zoopla',
#   'tags': ['No Smoking', 'No pets'],
#   'title': '2 bed flat to rent'},
#  {'address': {'area': 'Meadowbank',
#    'city': 'Edinburgh',
#    'latitude': 55.95819,
#    'longitude': -3.163338,
#    'postcode': 'EH7',
#    'street': 'Moray Park Terrace',
#    'tags': []},
#   'description': ' Delightfully presented two bedroom furnished property in modern development with excellent local amenities within walking distance. The property comprises of welcoming entrance hall area with storage, spacious lounge, new fully fitted kitchen with dining area, two generous double bedrooms with built in wardrobes and modern fitted shower room. The property comes fully furnished and also benefits from GCH, dg, allocated parking space, secure entry phone and well maintained communal grounds. Located adjacent to Meadowbank Retail Centre which has a large Sainsburys Supermarket this property is well located for the local amenities, and also offers excellent public transport to Edinburgh city centre, which is a short journey away, as well as other parts of Edinburgh and surrounding areas.Deposit: £990Landlord registration: 40759/230/24070 ',
#   'href': 'https://www.zoopla.co.uk/to-rent/details/46425422',
#   'key_info': {'council_tax': None,
#    'date_available': '25/02/2018',
#    'deposit': None,
#    'epc': None,
#    'furnishing': 'furnished',
#    'letting_type': None,
#    'rent': 890.0,
#    'running_costs': {'council_tax': None,
#     'energy': 79.0,
#     'insurrance': 19.0,
#     'water': 53.0}},
#   'source': 'zoopla',
#   'tags': ['Fridge Freezer',
#    'Washer Dryer',
#    'Private Parking',
#    'Shower',
#    'Smoke Detector',
#    'Double Glazing',
#    'Laminate Flooring',
#    'All White Goods',
#    'No Smoking',
#    'No pets',
#    'No DSS',
#    '1st Floor',
#    'No Children',
#    'Secure Entry',
#    'EPC Rating - C',
#    'Council Tax Band - D',
#    'Gas CH',
#    'Fitted Kitchen'],
#   'title': '2 bed flat to rent'},
#  {'address': {'area': 'Abbeyhill',
#    'city': 'Edinburgh',
#    'latitude': 55.95484,
#    'longitude': -3.158369,
#    'postcode': 'EH8',
#    'street': 'Royal Park Terrace',
#    'tags': []},
#   'description': " Fabulous second floor flat offering stunning viewings of Arthur's Seat. The property comprises; Double master bedroom and second double bedroom with loft style bed, open plan lounge/kitchen, separate WC and shower-room. Located minutes from Edinburgh's famous Royal Mile and Meadowbank Retail Park. Please note some items in the photos are for display purposes only. Viewing highly recommended. EPC rating: D. Landlord Registration Number: 364970/230/21241.Deposit: £975 ",
#   'href': 'https://www.zoopla.co.uk/to-rent/details/46335077',
#   'key_info': {'council_tax': None,
#    'date_available': '25/02/2018',
#    'deposit': None,
#    'epc': None,
#    'furnishing': 'furnished',
#    'letting_type': None,
#    'rent': 875.0,
#    'running_costs': {'council_tax': None,
#     'energy': 79.0,
#     'insurrance': 29.0,
#     'water': 53.0}},
#   'source': 'zoopla',
#   'tags': ['No Smoking', 'No pets', 'On Street Parking'],
#   'title': '2 bed flat to rent'},
#  {'address': {'area': 'New Town',
#    'city': 'Edinburgh',
#    'latitude': 55.95405,
#    'longitude': -3.187638,
#    'postcode': 'EH1',
#    'street': 'Leith Street',
#    'tags': []},
#   'description': " Large lounge with dining/study area, modern kitchen, bathroom with shower. The property offers a great location next to Waverley train station and Princes Street. The apartment itself is very spacious and very well presented. The key feature is the very large lounge which has enough additional space to configure as a study or dining area. Complimented by modern kitchen and bathroom and two good sized bedrooms with great storage, this apartment will suit two professional individuals or a professional couple.Leith Street's location is simply superb! St James shopping Centre, Waverley Train Station and Princes Street are all within seconds of your front door, but dont worry, this apartment is located on the first floor and benefits from secondary glazing so once you are inside you would never know that you were in such a bustling part of Scotland's capital city.Deposit: £895 ",
#   'href': 'https://www.zoopla.co.uk/to-rent/details/46285314',
#   'key_info': {'council_tax': None,
#    'date_available': '05/03/2018',
#    'deposit': None,
#    'epc': None,
#    'furnishing': 'unfurnished',
#    'letting_type': None,
#    'rent': 895.0,
#    'running_costs': {'council_tax': None,
#     'energy': 79.0,
#     'insurrance': 32.0,
#     'water': 53.0}},
#   'source': 'zoopla',
#   'tags': None,
#   'title': '2 bed flat to rent'},
#  {'address': {'area': None,
#    'city': 'Edinburgh',
#    'latitude': 55.95061,
#    'longitude': -3.183545,
#    'postcode': 'EH8',
#    'street': 'Canongate',
#    'tags': []},
#   'description': ' Spacious 2 bedroom 1st floor flat situated on The Royal Mile. This property is in the heart of the city. A short walk to Waverly Station, Holyrood Palace and Edinburgh Castle. The property also benefits from an abundance of local amenities within walking distance and good transport links. Comprises: Entrance hallway with storage, lounge with dining area and separate kitchen off, bathroom with shower over bath, 2 double bedrooms (1 with en-suite shower room). GCH and zone parking. EPC - C Council Tax Band- D Landlord Reg- 635873/230/12121Deposit: £1,075 ',
#   'href': 'https://www.zoopla.co.uk/to-rent/details/46278745',
#   'key_info': {'council_tax': None,
#    'date_available': '25/02/2018',
#    'deposit': None,
#    'epc': None,
#    'furnishing': 'furnished',
#    'letting_type': None,
#    'rent': 975.0,
#    'running_costs': {'council_tax': None,
#     'energy': 79.0,
#     'insurrance': 19.0,
#     'water': 53.0}},
#   'source': 'zoopla',
#   'tags': ['Central Heating'],
#   'title': '2 bed flat to rent'},
#  {'address': {'area': None,
#    'city': 'Edinburgh',
#    'latitude': 55.955257,
#    'longitude': -3.148595,
#    'postcode': 'EH8',
#    'street': 'Portobello Road',
#    'tags': []},
#   'description': ' Viewing recommendedThis is a newly decorated (largely unfurnished) second floor flat with 2 double bedrooms (master with extensive fitted wardrobes), spacious lounge (gas fire with back boiler) fully fitted kitchen (electric cooker, fridge-freezer and washing machine), hall with storage, large bathroom with white suite (basin in vanity unit), electric shower over the bath and medicine cabinet.With carpets throughout (except laminate floor in the hall) and curtains throughout, this property is ready to move into.Fully double-glazed and close to all local and shopping amenities as well as public transport links.Deposit: £850Landlord registration: 632985/230/05121 ',
#   'href': 'https://www.zoopla.co.uk/to-rent/details/46138244',
#   'key_info': {'council_tax': None,
#    'date_available': '25/02/2018',
#    'deposit': None,
#    'epc': None,
#    'furnishing': 'unfurnished',
#    'letting_type': None,
#    'rent': 750.0,
#    'running_costs': {'council_tax': None,
#     'energy': 79.0,
#     'insurrance': 15.0,
#     'water': 53.0}},
#   'source': 'zoopla',
#   'tags': ['Fridge Freezer',
#    'Washing Machine',
#    'Electric Hob',
#    'Electric Oven',
#    'Central Heating',
#    'Shared Garden',
#    'Parking',
#    'Shower',
#    'Smoke Detector',
#    'Double Glazing',
#    'Carpet Flooring',
#    'Laminate Flooring',
#    'All White Goods',
#    'No Smoking',
#    'No pets',
#    'No DSS',
#    '2nd Floor',
#    'Children Welcome',
#    'Not hmo',
#    'Public Transport Links',
#    'Secure Entry',
#    'EPC Rating - C',
#    'Council Tax Band - B',
#    'Gas CH',
#    'Bath',
#    'Fitted Kitchen',
#    'On Street Parking'],
#   'title': '2 bed flat to rent'},
#  {'address': {'area': None,
#    'city': 'Edinburgh',
#    'latitude': 55.951656,
#    'longitude': -3.217656,
#    'postcode': 'EH4',
#    'street': 'Hawthornbank Lane',
#    'tags': []},
#   'description': " Bright and spacious first floor property in a highly desirable residential development, close to the West End and excellent local amenities. The property comprises of lounge with small fireplace, spacious dining area and fully fitted modern kitchen off. The kitchen benefits from Integrated fridge freezer, dishwasher, electric hob and oven. There are two double bedrooms, master has a large mirrored built in wardrobe offering excellent storage and ensuite bathroom with white suite and shower over the bath. Second bedroom also has an ensuite shower room which can be accessed from the hallway to provide facilities for living area. Good storage in the hall and the washing machine is housed in a 'utility' cupboard. Electric heating with timers and double glazing throughout. Available furnished. EPC - C Council Tax Band - F Landlord Reg - 400521/230/18071Deposit: £1,100 ",
#   'href': 'https://www.zoopla.co.uk/to-rent/details/45753616',
#   'key_info': {'council_tax': None,
#    'date_available': '25/02/2018',
#    'deposit': None,
#    'epc': None,
#    'furnishing': 'furnished',
#    'letting_type': None,
#    'rent': 1000.0,
#    'running_costs': {'council_tax': None,
#     'energy': 79.0,
#     'insurrance': 19.0,
#     'water': 53.0}},
#   'source': 'zoopla',
#   'tags': ['Dishwasher'],
#   'title': '2 bed flat to rent'}]

# %%
from propertyscraper.search import RentedSearch

link = "http://www.rightmove.co.uk/property-to-rent/find.html?minBedrooms=2&sortType=6&viewType=LIST&channel=RENT&index=0&maxPrice=1000&radius=0.0&numberOfPropertiesPerPage=499&locationIdentifier=USERDEFINEDAREA%5E%7B%22polylines%22%3A%22kcmtIfpjRhZ%7ELzXnmBxFlqCmb%40hw%40qgAs%5Euu%40qaA_N_uB%7ESmq%40d%5Ds%7B%40n%60A%3F%22%7D"
search = RentedSearch.from_rightmove(link)
[item.to_json() for item in search.data]
# Out:
# [{'address': {'area': None,
#    'city': None,
#    'latitude': None,
#    'longitude': None,
#    'postcode': 'EH3',
#    'street': None,
#    'tags': ['Upper Grove Place', 'Edinburgh']},
#   'description': 'FABULOUS AND UNIQUE 2 bedroom flat in convenient location. 5 minute walk from Princess Street. This flat is presented in a contemporary fashion with stunning exposed stonework in lounge and kitchen. Modern fitted kitchen, bright living room with box style bedroom off. Modern bathroom and further double bedroom. Great property in fantastic location. Must be seen! Energy Efficiency Rating: C. Landlord Registration: 135182/230/03160. Professionals Only!',
#   'href': 'http://www.rightmove.co.uk/property-to-rent/property-71701382.html',
#   'key_info': {'council_tax': None,
#    'date_available': '09/04/2018',
#    'deposit': 835.0,
#    'epc': None,
#    'furnishing': 'Furnished',
#    'letting_type': None,
#    'rent': 835.0,
#    'running_costs': {'council_tax': None,
#     'energy': None,
#     'insurrance': None,
#     'water': None}},
#   'source': 'rightmove',
#   'tags': ['Fantastic area!',
#    'Close to Haymarket Station',
#    'Gas Central Heating'],
#   'title': '2 bedroom flat to rent'},
#  {'address': {'area': None,
#    'city': None,
#    'latitude': None,
#    'longitude': None,
#    'postcode': None,
#    'street': None,
#    'tags': ['East Crosscauseway', 'Newington', 'Edinburgh']},
#   'description': 'Bright FURNISHED second floor two bedroom flat located in the extremely popular area of Newington/The Pleasance, with plenty of amenities on the doorstep and good bus links across the city.The property comprises an entrance hall,an open plan living room / kitchen,sunny double bedroom, a possible guest single bedroom and shower room/WC. Sorry no smokers or pets, suitable for Mature Students / Professionals.Landlord Registration: 178023/230/27450EPC rating: E ',
#   'href': 'http://www.rightmove.co.uk/property-to-rent/property-52589718.html',
#   'key_info': {'council_tax': None,
#    'date_available': '26/03/2018',
#    'deposit': 925.0,
#    'epc': None,
#    'furnishing': 'Furnished',
#    'letting_type': 'Long term',
#    'rent': 725.0,
#    'running_costs': {'council_tax': None,
#     'energy': None,
#     'insurrance': None,
#     'water': None}},
#   'source': 'rightmove',
#   'tags': ['Parking: Permit Zone',
#    'Council Tax Band B',
#    'Double Bedrooms: 1',
#    'Secure Entry Phone',
#    'Single Bedrooms: 1',
#    'Shower',
#    'Fridge Freezer',
#    'Electric Oven',
#    'Electric Hob',
#    'Washing Machine'],
#   'title': '2 bedroom flat to rent'},
#  {'address': {'area': None,
#    'city': None,
#    'latitude': None,
#    'longitude': None,
#    'postcode': 'EH3',
#    'street': None,
#    'tags': ['Lochrin Buildings ', 'Tollcross', 'Edinburgh']},
#   'description': 'An attractive two double bedroom first floor furnished flat in a central location.Available furnished and immediately, this bright flat comprises of; two double bedrooms, large storage cupboard, bathroom and an open plan kitchen reception with modern appliances. EPC rating: C. Landlord Registration Number: 648695/230/15011.',
#   'href': 'http://www.rightmove.co.uk/property-to-rent/property-71683211.html',
#   'key_info': {'council_tax': None,
#    'date_available': '27/02/2018',
#    'deposit': 1195.0,
#    'epc': None,
#    'furnishing': 'Furnished',
#    'letting_type': 'Long term',
#    'rent': 995.0,
#    'running_costs': {'council_tax': None,
#     'energy': None,
#     'insurrance': None,
#     'water': None}},
#   'source': 'rightmove',
#   'tags': ['Washing machine',
#    'Shower',
#    'Fridge Freezer',
#    'Double glazing',
#    'Dishwasher'],
#   'title': '2 bedroom flat to rent'},
#  {'address': {'area': None,
#    'city': None,
#    'latitude': None,
#    'longitude': None,
#    'postcode': None,
#    'street': None,
#    'tags': ['Bernard Terrace', 'Newington', 'Edinburgh']},
#   'description': 'Excellent FURNISHED two double bedroom flat situated in the heart of Newington, an ideal location, close to Edinburgh University, The Meadows and has excellent local amenities and public transport service.The property comprises of hallway, large living room with dining area, fully fitted and integrated kitchen, two double bedrooms and bathroom with shower. The property benefits further from central heating, entry phone access and permit zone parking No smoker or pets allowedLandlord registration: 471764/230/22441EPC rating: D ',
#   'href': 'http://www.rightmove.co.uk/property-to-rent/property-52049370.html',
#   'key_info': {'council_tax': None,
#    'date_available': 'Now',
#    'deposit': 1095.0,
#    'epc': None,
#    'furnishing': 'Furnished',
#    'letting_type': 'Long term',
#    'rent': 895.0,
#    'running_costs': {'council_tax': None,
#     'energy': None,
#     'insurrance': None,
#     'water': None}},
#   'source': 'rightmove',
#   'tags': ['Council Tax Band E',
#    'Double Bedrooms: 2',
#    'Central Heating Gas',
#    'Parking: Permit Zone',
#    'Bath',
#    'Shower',
#    'Gas Hob',
#    'Gas Oven',
#    'Washing Machine',
#    'Fridge Freezer'],
#   'title': '2 bedroom flat to rent'},
#  {'address': {'area': None,
#    'city': None,
#    'latitude': None,
#    'longitude': None,
#    'postcode': None,
#    'street': None,
#    'tags': ['Viewforth', 'Bruntsfield', 'Edinburgh']},
#   'description': 'Well presented, second floor FURNISHED two double bedroom flat set just off Bruntsfield in the popular area of Viewforth with fantastic local amenities including leisure facilitates at Fountainpark, and good transport links, a great location for Edinburgh University and Napier Merchiston campus students. The flat comprises of a good-sized open plan kitchen with lounge area, two double bedrooms, and bathroom with shower. The flat benefits from gas central heating and ample storage, with an excellent standard of decor throughout. Landlord Registration: 51428/230/27210EPC rating: C',
#   'href': 'http://www.rightmove.co.uk/property-to-rent/property-52561479.html',
#   'key_info': {'council_tax': None,
#    'date_available': 'Now',
#    'deposit': 1125.0,
#    'epc': None,
#    'furnishing': 'Furnished',
#    'letting_type': 'Long term',
#    'rent': 925.0,
#    'running_costs': {'council_tax': None,
#     'energy': None,
#     'insurrance': None,
#     'water': None}},
#   'source': 'rightmove',
#   'tags': ['Central Heating Gas',
#    'Council Tax Band D',
#    'Double Bedrooms: 2',
#    'Garden Access',
#    'Parking: Permit Zone',
#    'Shower',
#    'Bath',
#    'Gas Oven',
#    'Gas Hob',
#    'Washing Machine'],
#   'title': '2 bedroom flat to rent'},
#  {'address': {'area': None,
#    'city': None,
#    'latitude': None,
#    'longitude': None,
#    'postcode': None,
#    'street': None,
#    'tags': ['Terrars Croft', 'Edinburgh', '']},
#   'description': 'Delightful 2 double bedroom apartment with modern and spacious kitchen, dining lounge and wonderful stylish tiled bathroom with shower. Complimented by quality furniture, gas central heating and a private allocated car parking space. The property has been freshly repainted and is presented to a high standard.SITUATIONTerrars Croft is a modern residential development built in 1997. Tucked in behind Parkside and St Leonards this is a quiet and peaceful location but with the added bonus of having the hustle and bustle of The Causewayside and its local shops, bars and restaurants within minutes walk. A new welcome addition is the Tesco Metro which offers more conventional shopping. The large golden grass of The Meadows offers excellent outdoor space for running, playing sports or simply just relaxing in the shadow of Arthurs Seat. A footpath through The Meadows offers quick and easy access to the City Centre and in particular the Old Town. Edinburgh University, Napier University, Bruntsfield and Morningside are all within easy walking distance from this very attractive apartment',
#   'href': 'http://www.rightmove.co.uk/property-to-rent/property-64179412.html',
#   'key_info': {'council_tax': None,
#    'date_available': '05/03/2018',
#    'deposit': 850.0,
#    'epc': None,
#    'furnishing': 'Furnished',
#    'letting_type': 'Long term',
#    'rent': 850.0,
#    'running_costs': {'council_tax': None,
#     'energy': None,
#     'insurrance': None,
#     'water': None}},
#   'source': 'rightmove',
#   'tags': None,
#   'title': '2 bedroom flat to rent'},
#  {'address': {'area': None,
#    'city': None,
#    'latitude': None,
#    'longitude': None,
#    'postcode': None,
#    'street': 'Leith Street',
#    'tags': ['Edinburgh', '']},
#   'description': "Large lounge with dining/study area, modern kitchen, bathroom with shower. The property offers a great location next to Waverley train station and Princes Street. The apartment itself is very spacious and very well presented. The key feature is the very large lounge which has enough additional space to configure as a study or dining area. Complimented by modern kitchen and bathroom and two good sized bedrooms with great storage, this apartment will suit two professional individuals or a professional couple.Leith Street's location is simply superb! St James shopping Centre, Waverley Train Station and Princes Street are all within seconds of your front door, but dont worry, this apartment is located on the first floor and benefits from secondary glazing so once you are inside you would never know that you were in such a bustling part of Scotland's capital city.",
#   'href': 'http://www.rightmove.co.uk/property-to-rent/property-63614986.html',
#   'key_info': {'council_tax': None,
#    'date_available': '05/03/2018',
#    'deposit': 895.0,
#    'epc': None,
#    'furnishing': 'Unfurnished',
#    'letting_type': 'Long term',
#    'rent': 895.0,
#    'running_costs': {'council_tax': None,
#     'energy': None,
#     'insurrance': None,
#     'water': None}},
#   'source': 'rightmove',
#   'tags': None,
#   'title': '2 bedroom flat to rent'},
#  {'address': {'area': None,
#    'city': None,
#    'latitude': None,
#    'longitude': None,
#    'postcode': 'EH3',
#    'street': None,
#    'tags': ['High Riggs', 'Tollcross', 'Edinburgh']},
#   'description': '**Available 12th March** FURNISHED ground floor two bedroom flat. Property will be freshly decorated with new carpets and painting throughout. Open plan living room with plenty space for separate dining and living areas with separated kitchen space, DOUBLE bedroom, SINGLE bedroom, bathroom with electric shower over bath. Double glazing. This central location is ideal for people new to Edinburgh, mature students and professionals. Council tax band B. Deposit £995. Landlord registration 82775/230/18240. EPC rating D. No pets. No smoking in or near the property. EPC rating: D. Landlord Registration Number: 82775/230/18240.',
#   'href': 'http://www.rightmove.co.uk/property-to-rent/property-53036463.html',
#   'key_info': {'council_tax': None,
#    'date_available': '12/03/2018',
#    'deposit': 995.0,
#    'epc': None,
#    'furnishing': 'Furnished',
#    'letting_type': 'Long term',
#    'rent': 795.0,
#    'running_costs': {'council_tax': None,
#     'energy': None,
#     'insurrance': None,
#     'water': None}},
#   'source': 'rightmove',
#   'tags': ['Washing machine', 'Shower', 'Fridge Freezer', 'Double glazing'],
#   'title': '2 bedroom flat to rent'},
#  {'address': {'area': None,
#    'city': None,
#    'latitude': None,
#    'longitude': None,
#    'postcode': None,
#    'street': None,
#    'tags': ['Livingstone Place', 'Sciennes', 'Edinburgh']},
#   'description': 'Centrally located FURNISHED two bedroom flat located seconds from the Meadows and close to excellent bus links, shops and the University. This well-proportioned flat comprises of a hallway, good size lounge, fully fitted kitchen, utility room, double bedroom, single bedroom and bathroom with shower. The property further benefits from gas central heating, entry phone access, permit zone parking and shared rear garden. Professionals only, no smokers or pets allowed. Landlord Registration No: 92556/230/03090EPC Rating: C',
#   'href': 'http://www.rightmove.co.uk/property-to-rent/property-52157724.html',
#   'key_info': {'council_tax': None,
#    'date_available': 'Now',
#    'deposit': 1050.0,
#    'epc': None,
#    'furnishing': 'Furnished',
#    'letting_type': 'Long term',
#    'rent': 850.0,
#    'running_costs': {'council_tax': None,
#     'energy': None,
#     'insurrance': None,
#     'water': None}},
#   'source': 'rightmove',
#   'tags': ['Double Bedrooms: 1',
#    'Single Bedrooms: 1',
#    'Garden Access',
#    'Parking: Permit Zone',
#    'Central Heating Gas',
#    'Council Tax Band D',
#    'Bath',
#    'Shower',
#    'Electric Hob',
#    'Electric Oven'],
#   'title': '2 bedroom flat to rent'},
#  {'address': {'area': None,
#    'city': None,
#    'latitude': None,
#    'longitude': None,
#    'postcode': None,
#    'street': None,
#    'tags': ['Blackwood Crescent', 'Newington', 'Edinburgh']},
#   'description': 'Stunningly presented FURNISHED two double bedroom flat set in the popular student area of Newington, close to close to excellent local shops, including a Sainsbury Local and Tesco Express, and a selection of bars, restaurants & cafes. Well placed for the University, Royal Commonwealth Pool and for walks around the Meadows and Holyrood Park. The property comprises of a large open plan lounge/kitchen, two good sized double bedrooms and modern fitted shower room Further benefits include gas central heating, full double glazing and ample storage The property has been finished to the highest of standards.Landlord Registration Number: 511951/230/22031EPC Rating: C',
#   'href': 'http://www.rightmove.co.uk/property-to-rent/property-52627572.html',
#   'key_info': {'council_tax': None,
#    'date_available': 'Now',
#    'deposit': 1175.0,
#    'epc': None,
#    'furnishing': 'Furnished',
#    'letting_type': 'Long term',
#    'rent': 975.0,
#    'running_costs': {'council_tax': None,
#     'energy': None,
#     'insurrance': None,
#     'water': None}},
#   'source': 'rightmove',
#   'tags': ['Central Heating Gas',
#    'Double Glazed',
#    'Double Bedrooms: 2',
#    'Fridge Freezer',
#    'Washing Machine',
#    'Electric Hob',
#    'Electric Oven',
#    'Shower',
#    'No Smoking'],
#   'title': '2 bedroom flat to rent'},
#  {'address': {'area': None,
#    'city': None,
#    'latitude': None,
#    'longitude': None,
#    'postcode': None,
#    'street': None,
#    'tags': ['Gilmours Entry', 'Newington', 'Edinburgh']},
#   'description': "Excellent FURNISHED ground floor two bedroom flat close to Edinburgh's City Centre with excellent local amenities and a good public transport service.The flat comprises of a hallway, lounge with dining area, fitted kitchen, single bedroom, good size double bedroom and bathroom with shower. The flat further benefits from gas central heating, a secure Entryphone system and private parking. Suitable for Mature Students and Professionals. Landlord Registration: 117034/230/12270EPC Rating: C",
#   'href': 'http://www.rightmove.co.uk/property-to-rent/property-52332516.html',
#   'key_info': {'council_tax': None,
#    'date_available': '08/03/2018',
#    'deposit': 1050.0,
#    'epc': None,
#    'furnishing': 'Furnished',
#    'letting_type': 'Long term',
#    'rent': 850.0,
#    'running_costs': {'council_tax': None,
#     'energy': None,
#     'insurrance': None,
#     'water': None}},
#   'source': 'rightmove',
#   'tags': ['Council Tax Band C',
#    'Secure Entry Phone',
#    'Central Heating Gas',
#    'Private Parking',
#    'Double Bedrooms: 1',
#    'Single Bedrooms: 1',
#    'Bath',
#    'Shower',
#    'Electric Hob',
#    'Microwave'],
#   'title': '2 bedroom flat to rent'},
#  {'address': {'area': None,
#    'city': None,
#    'latitude': None,
#    'longitude': None,
#    'postcode': None,
#    'street': None,
#    'tags': ['The Pleasance', 'Edinburgh']},
#   'description': '/REF: 1537 - THE PLEASANCE, OLD TOWNNewly refurbished & redecorated to a high standard. Centrally located two bedroom, first floor flat. Accommodation comprises lounge with dining area, fully fitted kitchen, two double bedrooms and shower room. The property has gas central heating, shared rear garden and zone parking. Council tax band B. Energy Performance rating D. Landlord Registration No: 32889/230/18280. This property is available now',
#   'href': 'http://www.rightmove.co.uk/property-to-rent/property-52632474.html',
#   'key_info': {'council_tax': None,
#    'date_available': 'Now',
#    'deposit': 995.0,
#    'epc': None,
#    'furnishing': 'Furnished',
#    'letting_type': None,
#    'rent': 895.0,
#    'running_costs': {'council_tax': None,
#     'energy': None,
#     'insurrance': None,
#     'water': None}},
#   'source': 'rightmove',
#   'tags': ['EPC D',
#    'Two bedroom first floor flat',
#    'Gas central heating',
#    'Shared rear garden',
#    'Zone parking',
#    'Council tax B'],
#   'title': '2 bedroom apartment to rent'},
#  {'address': {'area': None,
#    'city': None,
#    'latitude': None,
#    'longitude': None,
#    'postcode': None,
#    'street': None,
#    'tags': ['Grassmarket', 'Old Town', 'Edinburgh']},
#   'description': "Centrally located FURNISHED first floor two double bedroom flat located right in the heart of Edinburgh's old town. With windows looking out directly onto Grassmarket which has many excellent pubs, restaurants and shops. The flat is also just a short jaunt up castle hill to get to Princes Street which has bus routes to everywhere in the city, as well as Edinburgh Waverley station.The flat comprises of a comfortable living room with small dining area, Fitted kitchen, two double bedrooms and bathroom with shower, Further benefits include gas central heating, gas oven, and the excellent location.Landlord Registration: 101515/230/27300EPC Rating:C",
#   'href': 'http://www.rightmove.co.uk/property-to-rent/property-52958376.html',
#   'key_info': {'council_tax': None,
#    'date_available': '06/04/2018',
#    'deposit': 1195.0,
#    'epc': None,
#    'furnishing': 'Furnished',
#    'letting_type': 'Long term',
#    'rent': 995.0,
#    'running_costs': {'council_tax': None,
#     'energy': None,
#     'insurrance': None,
#     'water': None}},
#   'source': 'rightmove',
#   'tags': ['Double Bedrooms: 2',
#    'Central Heating Gas',
#    'Carpet Flooring',
#    'Council Tax Band E',
#    'Smoke Detector',
#    'Gas Oven',
#    'Gas Hob',
#    'Washing Machine',
#    'Fridge',
#    'Bath'],
#   'title': '2 bedroom flat to rent'},
#  {'address': {'area': None,
#    'city': None,
#    'latitude': None,
#    'longitude': None,
#    'postcode': None,
#    'street': 'William Street',
#    'tags': ['Edinburgh', '']},
#   'description': 'A delightful 2 bed first floor flat situated in a much sought after location within the West End Village.The spacious and pleasant accommodation is on the 1st floor, and internally comprises 2 double bedrooms, bright south facing kitchen with modern appliances, separate WC and shower room with power shower and a delightiful tile surround, plenty hall storage and a large, bright living room with traditional features and Edinburgh press cupboard.This property would idally suit two individual professionals or PHD students, or a professional couple.Further benefits are GCH and combi boiler.The West End offers excellent facilities with a wide range of quality shopping within easy walking distance of the property and a good choice of fashionable restaurants, bars and bistros, leisure and recreational facilities and all the usual amenities.There is excellent schooling at both primary and secondary levels within the public and private sector. In addition the property is well placed for the financial and commercial district of the City. Haymarket Station is nearby with frequent services operating to Glasgow and the main Scottish towns and Cities and there is good access via Corstorphine Road to the City Bypass, airport and motorway routes north and west.',
#   'href': 'http://www.rightmove.co.uk/property-to-rent/property-52897554.html',
#   'key_info': {'council_tax': None,
#    'date_available': '27/03/2018',
#    'deposit': 995.0,
#    'epc': None,
#    'furnishing': 'Furnished',
#    'letting_type': 'Long term',
#    'rent': 995.0,
#    'running_costs': {'council_tax': None,
#     'energy': None,
#     'insurrance': None,
#     'water': None}},
#   'source': 'rightmove',
#   'tags': None,
#   'title': '2 bedroom flat to rent'},
#  {'address': {'area': None,
#    'city': None,
#    'latitude': None,
#    'longitude': None,
#    'postcode': None,
#    'street': None,
#    'tags': ['Sciennes', 'Marchmont', 'Edinburgh']},
#   'description': 'Spacious FURNISHED two double bedroom flat in the well sought-after area of Marchmont. This property is a short walk from the city centre with easy access to bus links and to the beautiful Meadows.The property comprises entrance hall, bright spacious lounge, fitted kitchen, two double bedrooms and bathroom with shower, 2nd W/C room. The property further benefits from Electric central heating, close to Edinburgh University and council tax band C.Landlord registration: 2202287/230/04310EPC Rating F ',
#   'href': 'http://www.rightmove.co.uk/property-to-rent/property-71332193.html',
#   'key_info': {'council_tax': None,
#    'date_available': '09/04/2018',
#    'deposit': 1045.0,
#    'epc': None,
#    'furnishing': 'Furnished',
#    'letting_type': 'Long term',
#    'rent': 845.0,
#    'running_costs': {'council_tax': None,
#     'energy': None,
#     'insurrance': None,
#     'water': None}},
#   'source': 'rightmove',
#   'tags': ['Double Bedrooms: 2',
#    'Parking: Permit Zone',
#    'Electric Heating ',
#    'Council Tax Band C',
#    'Shower',
#    'Fridge Freezer',
#    'Microwave',
#    'Electric Hob',
#    'Electric Oven',
#    'Washing Machine'],
#   'title': '2 bedroom flat to rent'},
#  {'address': {'area': None,
#    'city': None,
#    'latitude': None,
#    'longitude': None,
#    'postcode': None,
#    'street': 'Northumberland Street',
#    'tags': ['New Town', 'Edinburgh']},
#   'description': 'This is a stunning bright and spacious FURNISHED two double bedroom basement flat located in the much sought after New Town area there are various fantastic local shops available as well as an excellent transport linksThe property benefits from having a large lounge with dining area and garden access through French doors, modern fitted kitchen with alcoves just off, two double bedrooms, bathroom with shower and separate utility room just outside the main door of the property with excellent storage capacity. The property offers gas central heating and double glazing and is decorated to a very high standard.Landlord Registration Number: 336053/230/29021EPC rating: C',
#   'href': 'http://www.rightmove.co.uk/property-to-rent/property-52840455.html',
#   'key_info': {'council_tax': None,
#    'date_available': '09/04/2018',
#    'deposit': 1195.0,
#    'epc': None,
#    'furnishing': 'Furnished',
#    'letting_type': 'Long term',
#    'rent': 995.0,
#    'running_costs': {'council_tax': None,
#     'energy': None,
#     'insurrance': None,
#     'water': None}},
#   'source': 'rightmove',
#   'tags': ['Double Bedrooms: 2',
#    'Council Tax Band D',
#    'Central Heating Gas',
#    'Double Glazed',
#    'Private Garden',
#    'Bath',
#    'Shower',
#    'Gas Hob',
#    'Gas Oven',
#    'Fridge Freezer'],
#   'title': '2 bedroom flat to rent'},
#  {'address': {'area': None,
#    'city': None,
#    'latitude': None,
#    'longitude': None,
#    'postcode': 'EH3',
#    'street': None,
#    'tags': ['Panmure Place', 'Edinburgh']},
#   'description': "REF: 1369L: PANMURE PLACE Spacious 2 bedroom flat located in a traditional tenement building on Panmure Place which is just off Brougham Street, a stone's throw from the Meadows. Tollcross is just seconds away which boasts a large number of amenities including shops, bars, pubs and restaurants. There are excellent transport links on offer and Princes Street is only a 10 minute walk. The 3rd (top) floor property has wooden flooring and neutral décor throughout. It is available FULLY FURNISHED and comprises: ~Bright, well-lit lounge with good seating, feature fireplace and large window ~Generous sized kitchen with all modern appliances and dining area for 6 ~Master bedroom with desk space and good storage ~Second bedroom with day-bed and bright outlook ~Bathroom with corner bath, tiled walls/floors and WC ~Communal rear garden ~Permit zone parking ~Gas heating ~Secure entry ~Sorry, no pets ~Council tax: band C ~EPC rating: C ~Landlord registration: 441846/230/24041 ~PLEASE NOTE: This property is not suitable for students Available: 27th March 2018 Rent: £925pcm Deposit: £925 Please note the photographs shown within this advertisement may have been taken whilst a tenancy was active in the property and as a result you should not rely on these as an accurate representation of furnishings and items included in the agreement. A full list of which items included in the property are available upon request from our office Property Reference: 1369L EDI PP ",
#   'href': 'http://www.rightmove.co.uk/property-to-rent/property-51068713.html',
#   'key_info': {'council_tax': None,
#    'date_available': '27/03/2018',
#    'deposit': 925.0,
#    'epc': None,
#    'furnishing': 'Furnished',
#    'letting_type': 'Long term',
#    'rent': 925.0,
#    'running_costs': {'council_tax': None,
#     'energy': None,
#     'insurrance': None,
#     'water': None}},
#   'source': 'rightmove',
#   'tags': ['Gas Heating',
#    'Secure Entry',
#    'Zone Parking',
#    'Communal Garden',
#    'White Goods'],
#   'title': '2 bedroom flat to rent'},
#  {'address': {'area': None,
#    'city': None,
#    'latitude': None,
#    'longitude': None,
#    'postcode': 'EH11',
#    'street': None,
#    'tags': ['Bryson Road', 'Edinburgh', 'Midlothian']},
#   'description': 'Very well presented 2 bedroom furnished property in a great location, close to city centre. The property comprises, 2 double bedrooms, both with neutral carpets and decor. Each bedroom is well furnished and has in built cupboard and wardrobe space. The living room has a wooden flooring and contemporary furniture and is complimented by its neutral decor. Furthermore, there is a great dining space. The kitchen has white fitted units and all kitchen appliances. It faces the back with a large window providing plenty of natural light. The bathroom is being renewed before the next tenancy with a new shower room. There is private permit parking. The property has electric panel heaters, secure entry and is double glazed. Fountainbridge is fantastically located for town and has the property has all local amenities to hand with Fountain Park a 2 min walk away. Strictly for a couple or individual. Landlord Registration: 11364/230/01080. EPC:D',
#   'href': 'http://www.rightmove.co.uk/property-to-rent/property-71124878.html',
#   'key_info': {'council_tax': None,
#    'date_available': 'Now',
#    'deposit': 875.0,
#    'epc': None,
#    'furnishing': 'Furnished',
#    'letting_type': None,
#    'rent': 875.0,
#    'running_costs': {'council_tax': None,
#     'energy': None,
#     'insurrance': None,
#     'water': None}},
#   'source': 'rightmove',
#   'tags': ['Private permit parking',
#    'Double Glazed',
#    'Very close to City Centre'],
#   'title': '2 bedroom flat to rent'},
#  {'address': {'area': None,
#    'city': None,
#    'latitude': None,
#    'longitude': None,
#    'postcode': None,
#    'street': 'Morrison Street',
#    'tags': ['West End', 'Edinburgh']},
#   'description': 'Well-presented second floor FURNISHED two double bedroom flat in superb central location within 10 minutes’ walk of Haymarket train station/Tram Line and Princes Street.The flat comprises of entrance hallway, open plan living room / kitchen with gas fire, two double bedrooms and bathroom with shower. The property also benefits from having gas central heating, Secure Entry Phone system and permit zone parking. Suitable for: professionals/mature students/non-smokers only.Landlord Registration: 10132/230/22060EPC rating: D',
#   'href': 'http://www.rightmove.co.uk/property-to-rent/property-52367112.html',
#   'key_info': {'council_tax': None,
#    'date_available': '28/02/2018',
#    'deposit': 1050.0,
#    'epc': None,
#    'furnishing': 'Furnished',
#    'letting_type': 'Long term',
#    'rent': 850.0,
#    'running_costs': {'council_tax': None,
#     'energy': None,
#     'insurrance': None,
#     'water': None}},
#   'source': 'rightmove',
#   'tags': ['Council Tax Band B',
#    'Central Heating Gas',
#    'Secure Entry Phone',
#    'Parking: Permit Zone',
#    'Bath',
#    'Shower',
#    'Washing Machine',
#    'Fridge',
#    'Freezer',
#    'Electric Oven'],
#   'title': '2 bedroom flat to rent'},
#  {'address': {'area': None,
#    'city': None,
#    'latitude': None,
#    'longitude': None,
#    'postcode': 'EH8',
#    'street': 'Collegiate Buccleuch Street',
#    'tags': ['Edinburgh']},
#   'description': 'Collegiate Buccleuch Street offers some of Edinburgh\'s finest student accommodation; residents can enjoy en-suite shower rooms, well-equipped kitchens and Wi-Fi included at no extra cost. While divided into studio, one, two and three bedroom apartments for maximum choice, the building outside each personal suite benefits from a host of luxury amenities. One of Collegiate Buccleuch Street\'s most exciting features is the in-house cinema, which is provided for resident\'s exclusive use. Here, take in the latest movies, kick back to comedy shows or catch the big game with your mates - the cinema room provides you with the perfect location to pursue your interests in good company. Healthy brain and body! - Keep fit and healthy during your uni years with a private gym for Collegiate Buccleuch Street residents. The gym is packed with the latest in fitness equipment, so you can keep in shape and burn off the stresses of academic life whenever you choose. As university is about more than just studying, make sure you take the time to relax and enjoy your student life in the games and common room here at Collegiate Buccleuch Street. With plenty of space to socialise with fellow residents and enjoy downtime, you\'ll be well relaxed for your studies - which can be done in the large study/workrooms provided on-site, allowing you to comfortably hit the books. One of the most important things in the modern student lifestyle is staying connected, to professors, classmates, or even just to browse social media - therefore at Collegiate Buccleuch Street you can stay online for the duration of your stay, with free high-speed broadband and Wi-Fi throughout the building. From studying in the workrooms to catching up with friends and family in your own room, bandwidth should never be an issue. For more information please visit our website: http://www.collegiate-ac.com/uk-student-accommodation/edinburgh/buccleuch-street/rooms-rent This really is Edinburgh student living. Just better. *Double occupancy is available- contact the site team for more information* ----------------------------------------------------------------------------------------------------- This advert is for an En-Suite room - costing £175.00 per week. 4ft Double Bed Desk Study Chair Double Wardrobe Shared kitchen/living space (shared between 4) 32" flat screen TV (TV licence not included) En-suite Bathroom ',
#   'href': 'http://www.rightmove.co.uk/property-to-rent/property-69936770.html',
#   'key_info': {'council_tax': None,
#    'date_available': '01/09/2018',
#    'deposit': 250.0,
#    'epc': None,
#    'furnishing': 'Furnished',
#    'letting_type': 'Student',
#    'rent': 175.0,
#    'running_costs': {'council_tax': None,
#     'energy': None,
#     'insurrance': None,
#     'water': None}},
#   'source': 'rightmove',
#   'tags': ['All inclusive rents - No extra bills',
#    "Large resident's games and common room",
#    'In-house cinema room',
#    "Resident's only private gym",
#    'Large communal study/work rooms',
#    'High speed broadband and Wi-Fi throughout',
#    'CCTV and secure door entry systems',
#    'On-site management team and 24 hour helpline'],
#   'title': '4 bedroom apartment to rent'},
#  {'address': {'area': None,
#    'city': None,
#    'latitude': None,
#    'longitude': None,
#    'postcode': 'EH3 8DX',
#    'street': None,
#    'tags': ['Morrison Circus', 'Edinburgh']},
#   'description': "Morrison Circus is a purpose built student accommodation block of 24 4 bedroom cluster flats ideal for University of Edinburgh, Heriot Watt or Edinburgh Napier University students. All flats within the building will come with double beds, 1 shared bathroom (But with 2 toilets in the flat) laundry facilities, a large open plan kitchen living dining room, bike parking and car parking (Available on request for an annual price).Each bedroom will include a double bed, a desk and storage space. On top of these fixtures all bills are included within the property at £17 per week. This includes water, electric, internet and TV license. This means hassle free living and no more headaches. Morrison Circus is located in a quiet residential area in the immediate vicinity of the Haymarket train and tram stop (Just a 6 minute walk away!) Furthermore Morrison Circus is just a short walk away from Edinburgh's West End, meaning you'll never be far from it's bohemian shops and much loved pubs and bars. ",
#   'href': 'http://www.rightmove.co.uk/property-to-rent/property-69451298.html',
#   'key_info': {'council_tax': None,
#    'date_available': '01/09/2018',
#    'deposit': None,
#    'epc': None,
#    'furnishing': 'Furnished',
#    'letting_type': 'Student',
#    'rent': 139.0,
#    'running_costs': {'council_tax': None,
#     'energy': None,
#     'insurrance': None,
#     'water': None}},
#   'source': 'rightmove',
#   'tags': ['Double Beds',
#    'Bike Parking',
#    'Car Parking On Request',
#    'Flatscreen TV',
#    'Dishwasher',
#    'Washing Machine',
#    'Dryer',
#    'Fast WiFi'],
#   'title': '4 bedroom flat to rent'},
#  {'address': {'area': None,
#    'city': None,
#    'latitude': None,
#    'longitude': None,
#    'postcode': 'EH8',
#    'street': 'Collegiate Buccleuch Street',
#    'tags': ['Edinburgh']},
#   'description': 'Collegiate Buccleuch Street offers some of Edinburgh\'s finest student accommodation; residents can enjoy en-suite shower rooms, well-equipped kitchens and Wi-Fi included at no extra cost. While divided into studio, one, two and three bedroom apartments for maximum choice, the building outside each personal suite benefits from a host of luxury amenities. One of Collegiate Buccleuch Street\'s most exciting features is the in-house cinema, which is provided for resident\'s exclusive use. Here, take in the latest movies, kick back to comedy shows or catch the big game with your mates - the cinema room provides you with the perfect location to pursue your interests in good company. Healthy brain and body! - Keep fit and healthy during your uni years with a private gym for Collegiate Buccleuch Street residents. The gym is packed with the latest in fitness equipment, so you can keep in shape and burn off the stresses of academic life whenever you choose. As university is about more than just studying, make sure you take the time to relax and enjoy your student life in the games and common room here at Collegiate Buccleuch Street. With plenty of space to socialise with fellow residents and enjoy downtime, you\'ll be well relaxed for your studies - which can be done in the large study/workrooms provided on-site, allowing you to comfortably hit the books. One of the most important things in the modern student lifestyle is staying connected, to professors, classmates, or even just to browse social media - therefore at Collegiate Buccleuch Street you can stay online for the duration of your stay, with free high-speed broadband and Wi-Fi throughout the building. From studying in the workrooms to catching up with friends and family in your own room, bandwidth should never be an issue. For more information please visit our website: http://www.collegiate-ac.com/uk-student-accommodation/edinburgh/buccleuch-street/rooms-rent This really is Edinburgh student living. Just better. *Double occupancy is available- contact the site team for more information* ----------------------------------------------------------------------------------------------------- This advert is for an En-Suite room - costing £175.00 per week. 4ft Double Bed Desk Study Chair Double Wardrobe Shared kitchen/living space (shared between 4) 32" flat screen TV (TV licence not included) En-suite Bathroom ',
#   'href': 'http://www.rightmove.co.uk/property-to-rent/property-40381836.html',
#   'key_info': {'council_tax': None,
#    'date_available': '01/09/2018',
#    'deposit': 250.0,
#    'epc': None,
#    'furnishing': 'Furnished',
#    'letting_type': 'Student',
#    'rent': 175.0,
#    'running_costs': {'council_tax': None,
#     'energy': None,
#     'insurrance': None,
#     'water': None}},
#   'source': 'rightmove',
#   'tags': ['All inclusive rents - No extra bills',
#    "Large resident's games and common room",
#    'In-house cinema room',
#    "Resident's only private gym",
#    'Large communal study/work rooms',
#    'High speed broadband and Wi-Fi throughout',
#    'CCTV and secure door entry systems',
#    'On-site management team and 24 hour helpline'],
#   'title': '4 bedroom private halls to rent'}]

# %%
from propertyscraper.search import RentedSearch

link = "https://www.gumtree.com/search?search_category=property-to-rent&search_location=edinburgh&q=&min_price=&max_price=400&min_property_number_beds=2&max_property_number_beds="
search = RentedSearch.from_gumtree(link)
[item.to_json() for item in search.data]
# Out:
# [{'address': {'area': None,
#    'city': None,
#    'latitude': 55.9347,
#    'longitude': -3.2634,
#    'postcode': None,
#    'street': None,
#    'tags': ['Stenhouse', 'Edinburgh']},
#   'description': " Spacious double bedroom to rent in a quiet area of Stenhouse, ground floor flat with double glazing and central heating close to the buses 22, 2, 1 and Tram 15 min to the city centre and 10 min to Sainsbury, LIDL, Aldi, Gyle Shopping Centre with Morrison. I own the flat so you'll be sharing it with myself and a ragdoll kitten named Muffin. Rent is £380+130 bills aprox. including council tax and £380 Deposit. Please no couples and no more pets. ",
#   'href': 'https://www.gumtree.com/p/property-to-rent/rent-a-room/1287853603',
#   'key_info': {'council_tax': None,
#    'date_available': '01/03/2018',
#    'deposit': None,
#    'epc': None,
#    'furnishing': None,
#    'letting_type': None,
#    'rent': 380.0,
#    'running_costs': {'council_tax': None,
#     'energy': None,
#     'insurrance': None,
#     'water': None}},
#   'source': 'gumtree',
#   'tags': None,
#   'title': 'Rent a room'},
#  {'address': {'area': None,
#    'city': None,
#    'latitude': 55.9041,
#    'longitude': -3.21642,
#    'postcode': None,
#    'street': None,
#    'tags': ['Colinton', 'Edinburgh']},
#   'description': ' Sunny top floor flat located in a quiet residential area, close to the amenities of Oxgangs and Fairmilehead, and ideally located close to the bypass. Unfurnished accommodation comprises 2 double bedrooms, (1 good sized double, 1 small double/large single), spacious lounge, fully fitted kitchen and bathroom with electric shower over bath. This property is in good condition with wooden flooring throughout, has electric white meter heating. It benefits from a private garage, and free on street parking. EPC Rating=F. Lld Reg: 109973/230/12160 Deposit:£985 ',
#   'href': 'https://www.gumtree.com/p/property-to-rent/2-bedroom-unfurnished-top-floor-flat-to-rent-on-caiystane-gardens-fairmilehead-edinburgh/1277300504',
#   'key_info': {'council_tax': None,
#    'date_available': '23/01/2018',
#    'deposit': None,
#    'epc': None,
#    'furnishing': None,
#    'letting_type': None,
#    'rent': 735.0,
#    'running_costs': {'council_tax': None,
#     'energy': None,
#     'insurrance': None,
#     'water': None}},
#   'source': 'gumtree',
#   'tags': None,
#   'title': '2 bedroom Unfurnished top floor flat to rent on Caiystane Gardens, Fairmilehead, Edinburgh'},
#  {'address': {'area': None,
#    'city': None,
#    'latitude': 55.9249,
#    'longitude': -3.2217,
#    'postcode': None,
#    'street': None,
#    'tags': ['Edinburgh']},
#   'description': ' Modern 1st floor flat with private residents parking and security entry system. Situated in the popular Morningside area with easy access to city centre and close to Napier University. Accommodation consists of 2 double bedrooms, lounge, fully fitted dining kitchen and bathroom with shower. The property also benefits from white meter heating and full Double Glazing. Private off-street parking is also included. Property comes fully furnished. EPC Rating=D. Lld Reg: 653117/230/23011 Deposit:£1045 ',
#   'href': 'https://www.gumtree.com/p/property-to-rent/2-bedroom-fully-furnished-1st-floor-flat-to-rent-on-craighouse-gardens-morningside-edinburgh/1287769474',
#   'key_info': {'council_tax': None,
#    'date_available': '23/02/2018',
#    'deposit': None,
#    'epc': None,
#    'furnishing': None,
#    'letting_type': None,
#    'rent': 795.0,
#    'running_costs': {'council_tax': None,
#     'energy': None,
#     'insurrance': None,
#     'water': None}},
#   'source': 'gumtree',
#   'tags': None,
#   'title': '2 bedroom fully furnished 1st floor flat to rent on Craighouse Gardens, Morningside , Edinburgh'},
#  {'address': {'area': None,
#    'city': None,
#    'latitude': 55.97116,
#    'longitude': -3.27081,
#    'postcode': None,
#    'street': None,
#    'tags': ['Silverknowes', 'Edinburgh']},
#   'description': ' Large semi-detached home on North side of Edinburgh. Fully furnished accommodation consists of 3 bedrooms with other attic bedroom/family room. Lounge/dining area with lovely conservatory extension to the rear, driveway to front, 3 bedrooms upstairs are 2 doubles and 1 single, shower room, good cupboard storage, lovely sun trap back garden. GCH. DG. Would suit family and has good amenities. Landlord registration : 455162/230/20251. EPC rating=D. Deposit:£1500 ',
#   'href': 'https://www.gumtree.com/p/property-to-rent/3-bedroom-fully-furnished-semi-detached-house-to-rent-on-silverknowes-place-silverknowes-edinburgh/1273774977',
#   'key_info': {'council_tax': None,
#    'date_available': '22/02/2018',
#    'deposit': None,
#    'epc': None,
#    'furnishing': None,
#    'letting_type': None,
#    'rent': 1250.0,
#    'running_costs': {'council_tax': None,
#     'energy': None,
#     'insurrance': None,
#     'water': None}},
#   'source': 'gumtree',
#   'tags': None,
#   'title': '3 bedroom fully furnished semi-detached house to rent on Silverknowes Place, Silverknowes, Edinburgh'},
#  {'address': {'area': None,
#    'city': None,
#    'latitude': 55.9229,
#    'longitude': -3.21115,
#    'postcode': None,
#    'street': None,
#    'tags': ['Comiston', 'Edinburgh']},
#   'description': ' Top floor flat in the popular Morningside area. Ideal accommodation for students with an HMO licence for 4 people. Large spacious property comprising 4 double bedrooms, kitchen with dining area, bathroom with shower, box room and plenty of storage. Property benefits from Gas Central Heating, sanded wooden flooring, access to a shared garden and a security entry system. EPC Rating = D. Lld Reg: 66751/230/09310. Deposit:£1950 ',
#   'href': 'https://www.gumtree.com/p/property-to-rent/4-bedroom-hmo-top-floor-flat-to-rent-on-comiston-road-morningside-edinburgh/1287642259',
#   'key_info': {'council_tax': None,
#    'date_available': '07/09/2018',
#    'deposit': None,
#    'epc': None,
#    'furnishing': None,
#    'letting_type': None,
#    'rent': 1700.0,
#    'running_costs': {'council_tax': None,
#     'energy': None,
#     'insurrance': None,
#     'water': None}},
#   'source': 'gumtree',
#   'tags': None,
#   'title': '4 bedroom HMO top floor flat to rent on Comiston Road, Morningside , Edinburgh'},
#  {'address': {'area': None,
#    'city': None,
#    'latitude': 55.9724,
#    'longitude': -3.20642,
#    'postcode': None,
#    'street': None,
#    'tags': ['Trinity', 'Edinburgh']},
#   'description': ' Well presented 1st floor, 2 bedroom flat situated in a quiet, well maintained modern development in the highly desirable area of Trinity. This property comprises good sized lounge, spacious fully fitted kitchen with modern appliances, two double bedrooms with built in wardrobes & spacious bathroom with shower over bath. This property also benefits from having carpets, gas central heating, double glazing and a secure entry system. EPC= C Lld reg: 556252/230/13071 Deposit:£1060 ',
#   'href': 'https://www.gumtree.com/p/property-to-rent/2-bedroom-fully-furnished-1st-floor-flat-to-rent-on-clark-place-trinity-edinburgh/1286124733',
#   'key_info': {'council_tax': None,
#    'date_available': '11/04/2018',
#    'deposit': None,
#    'epc': None,
#    'furnishing': None,
#    'letting_type': None,
#    'rent': 810.0,
#    'running_costs': {'council_tax': None,
#     'energy': None,
#     'insurrance': None,
#     'water': None}},
#   'source': 'gumtree',
#   'tags': None,
#   'title': '2 bedroom fully furnished 1st floor flat to rent on Clark Place, Trinity , Edinburgh'},
#  {'address': {'area': None,
#    'city': None,
#    'latitude': 55.8825,
#    'longitude': -3.33977,
#    'postcode': None,
#    'street': None,
#    'tags': ['Balerno', 'Edinburgh']},
#   'description': " Stunning 2 bedroom top floor apartment located in the village of Balerno on the outskirts of Edinburgh. Set within a factored building with private residents' parking, this property is well located for access to Heriot Watt University, City bypass, M8/motorway network & has frequent bus links to Edinburgh City centre which is only approx 6 miles away. Large entrance hallway with excellent storage space, impressive double-aspect lounge with floor-to-ceiling windows, open-plan kitchen area with quality integrated appliances, 2 double bedrooms, both with built-in wardrobes, master has bright en-suite shower room off & separate main bathroom. Wooden flooring throughout, GCH, DG, secure entry. EPC Rating=C. Lld reg: 427335/230/17211 Deposit:£1050 ",
#   'href': 'https://www.gumtree.com/p/property-to-rent/2-bedroom-part-furnished-2nd-floor-flat-to-rent-on-bavelaw-road-balerno-edinburgh/1285726122',
#   'key_info': {'council_tax': None,
#    'date_available': '05/02/2018',
#    'deposit': None,
#    'epc': None,
#    'furnishing': None,
#    'letting_type': None,
#    'rent': 800.0,
#    'running_costs': {'council_tax': None,
#     'energy': None,
#     'insurrance': None,
#     'water': None}},
#   'source': 'gumtree',
#   'tags': None,
#   'title': '2 bedroom part furnished 2nd floor flat to rent on Bavelaw Road, Balerno, Edinburgh'},
#  {'address': {'area': None,
#    'city': None,
#    'latitude': 55.9393,
#    'longitude': -3.21256,
#    'postcode': None,
#    'street': None,
#    'tags': ['Fountainbridge', 'Edinburgh']},
#   'description': ' Fully Serviced City Centre Apartments. Ideal for City Breaks, Sporting Weekends, Mid Week Stays. Available for immediate entry.  1, 2, 3 & 4 Bedroom Fully Serviced Apartments Edinburgh. From £60 per night, discount for longer term bookings. Save ££££££ and book direct.  Minimum Stay 3 Nights. Available 10th October 2017  CALL DIRECT FOR VERY COMPETITIVE RATES & FOR MORE INFORMATION ON HOW TO BOOK. 0131 656 0390 / 07791148722  ',
#   'href': 'https://www.gumtree.com/p/property-to-rent/fully-serviced-1-2-3-and-4-bedroom-apartments-available-for-short-term-lets./1183829873',
#   'key_info': {'council_tax': None,
#    'date_available': '10/10/2017',
#    'deposit': None,
#    'epc': None,
#    'furnishing': None,
#    'letting_type': None,
#    'rent': 1200.0,
#    'running_costs': {'council_tax': None,
#     'energy': None,
#     'insurrance': None,
#     'water': None}},
#   'source': 'gumtree',
#   'tags': None,
#   'title': 'Fully Serviced 1, 2, 3 and 4 Bedroom Apartments Available For Short Term Lets.'},
#  {'address': {'area': None,
#    'city': None,
#    'latitude': None,
#    'longitude': None,
#    'postcode': None,
#    'street': None,
#    'tags': ['Leith', 'Edinburgh']},
#   'description': ' Room A lovely and cosy double bedroom well situated in a 7 bedroom house. One of our flatmates is leaving so we are looking for someone that want to share our house. The price are 380£ per month + bills. The bedroom has a double bed and huge wardrobe, it\'s not available to smoke inside the house but don\'t worry if you are smoker, you can smoke in our cosy patio You have a shared bathroom with shower on the same floor.Lets talk about the house : A new fully-equipped kitchen with oven, 2 fridges, a freezer, a microwave, a kettle, a toaster. A lot of drawers and cupboards to stock your food (enough space for everyone). We have a blender as well, to do smoothies or sauces. The living-room just next to the kitchen, has a large sofa to welcome everybody and a big table for eat together. We have a TV to watch your favorites TV show or football games connecting your computer. Then the house has 2 bathrooms : one at the first floor with a bath, a toilet and a sink.The second one is at the second floor with a shower, a sink and a toilet.We have enough space for your bike.The house is situated on Ferry Road. You have ASDA, in 5 min by bus. Ocean Terminal ( shopping center and PureGym ) in 10 min by bus. LIDL in 10 min by bus. The surroundings are plenty of amenities !! Excellent connections with the city center. Bus number 11 ( Leith Walk in 5 min, Princess Street in 15 min). Buses number 7, 14, 21 ( bottom of Leith Walk in 10 min, North Bridge/Princess street in 20 min ).But, if you are "green" like some of us, you can just take the "Water of Leith Walk"!. A nice traffic-free path close to our house that brings you everywhere if you want to walk or cycle!!.And last but not least, 10 seconds away, we have a little shop for our basic necessities, open until 10pm ! Please keep in touch if you are interested and send us a PM ! We\'re waiting for you! :)Everybody is welcome.If you have any questions, please feel free! See ya ',
#   'href': 'https://www.gumtree.com/p/property-to-rent/double-room/1288401009',
#   'key_info': {'council_tax': None,
#    'date_available': '01/03/2018',
#    'deposit': None,
#    'epc': None,
#    'furnishing': None,
#    'letting_type': None,
#    'rent': 380.0,
#    'running_costs': {'council_tax': None,
#     'energy': None,
#     'insurrance': None,
#     'water': None}},
#   'source': 'gumtree',
#   'tags': None,
#   'title': 'Double room'},
#  {'address': {'area': None,
#    'city': None,
#    'latitude': 55.9591,
#    'longitude': -3.20421,
#    'postcode': None,
#    'street': None,
#    'tags': ['New Town', 'Edinburgh']},
#   'description': ' On the border of Stockbridge and New Town, this two bedroom, 2 bathroom apartment with private garage and good storage is available now. Enjoying a quiet location within easy walking distance of Edinburgh city centre and close to shops, library, restaurants and pubs, this delightful property is bright, spacious and in excellent decorative order. The property has been recently upgraded, including new main bathroom and a new gas boiler. The accommodation comprises two bedrooms, one with a king size pocket sprung bed and the other with a double pocket sprung, the master has an ensuite shower room and the main bathroom has a shower over the bath. There is a fully equipped dining kitchen and lounge with dining area. The property is fully factored at the owners expense, including maintenance of shared gardens and regular cleaning of halls. The flat is fitted with an alarm and entrance is via a secure entryphone. Ideal for 2 sharing professionals or a couple.   ',
#   'href': 'https://www.gumtree.com/p/property-to-rent/2-bed-flat-silvermills-eh3/1288392636',
#   'key_info': {'council_tax': None,
#    'date_available': '25/02/2018',
#    'deposit': None,
#    'epc': None,
#    'furnishing': None,
#    'letting_type': None,
#    'rent': 599.0,
#    'running_costs': {'council_tax': None,
#     'energy': None,
#     'insurrance': None,
#     'water': None}},
#   'source': 'gumtree',
#   'tags': None,
#   'title': '2 Bed Flat, Silvermills, EH3'},
#  {'address': {'area': None,
#    'city': None,
#    'latitude': 55.9742,
#    'longitude': -3.18471,
#    'postcode': None,
#    'street': None,
#    'tags': ['Bonnington', 'Edinburgh']},
#   'description': ' Located in the desirable Bonnington area of Edinburgh, a short walk to either the city centre or Leith (and close to No. 7, 10, 11, 14 and 21 bus stops). It is also close to the Water of Leith Walkway and cycle path, as well as local Ferry Road amenities. Flat includes hallway, lounge/kitchen, double bedroom, single bedroom/office, bathroom. The kitchen features a gas hob and electric oven, washing machine, and fridge freezer, as well as gas central heating throughout. The property is fully furnished and decorated in a contemporary style. The flat is in Council Tax band C, it has double glazing and fitted carpets/laminate. A quiet stair with respectful neighbours that would be suitable to a like-minded tenant. Would suit professional. Available immediately, and a fast move would be preferred. Rent £750 per month, Deposit £750. References will be required from employer & previous landlord. No Fees.   ',
#   'href': 'https://www.gumtree.com/p/property-to-rent/lovely-freshly-refurbished-2-bed-2nd-floor-flat-fully-furnished-/1288203769',
#   'key_info': {'council_tax': None,
#    'date_available': '25/02/2018',
#    'deposit': None,
#    'epc': None,
#    'furnishing': None,
#    'letting_type': None,
#    'rent': 750.0,
#    'running_costs': {'council_tax': None,
#     'energy': None,
#     'insurrance': None,
#     'water': None}},
#   'source': 'gumtree',
#   'tags': None,
#   'title': 'Lovely, freshly refurbished 2 bed 2nd floor flat (fully furnished) '},
#  {'address': {'area': None,
#    'city': None,
#    'latitude': 55.9736,
#    'longitude': -3.17165,
#    'postcode': None,
#    'street': None,
#    'tags': ['Leith', 'Edinburgh']},
#   'description': ' Available to view now an move in soon is this TWO BEDROOM FURNISHED apartment in a popular residential area of Leith close to all amenities with private parking. The property compromises of a large double bedroom with a large cupboard for storage, a single bedroom, a good sized bathroom with fitted units and a bathtub and shower, a good sized lounge dining area with large windows and lastly a fully equipped kitchen with all appliances. The block is serviced by a elevator and is close to all amenities. Modern city living at its very best... ***VIEW NOW***Agent: Affittoea LimitedAgent Ref: AFFITTOEALIMITED_AFF155 ',
#   'href': 'https://www.gumtree.com/p/property-to-rent/2-bedroom-flat-in-giles-street-edinburgh/1287392348',
#   'key_info': {'council_tax': None,
#    'date_available': '26/03/2018',
#    'deposit': None,
#    'epc': None,
#    'furnishing': None,
#    'letting_type': None,
#    'rent': 750.0,
#    'running_costs': {'council_tax': None,
#     'energy': None,
#     'insurrance': None,
#     'water': None}},
#   'source': 'gumtree',
#   'tags': None,
#   'title': '2 bedroom flat in Giles Street, Edinburgh'},
#  {'address': {'area': None,
#    'city': None,
#    'latitude': 55.9526,
#    'longitude': -3.1105,
#    'postcode': None,
#    'street': None,
#    'tags': ['Portobello', 'Edinburgh']},
#   'description': " Hello, I am Sabrina and I have a lovely, clean and cosy Double Bedroom to rent from Monday to Friday in Edinburgh suitable for one person only. It's a lovely, clean and confortable flat near the Sea, super close to the bus stops that takes you to all parts of Edinburgh, close to 3 supermarkets, Swimming Centre/ Gym, Restaurants and Bistros, lovely Coffe Shops, Library, Hair Dressers (all within one to two blocks from our flat), very quite stairs and our street is located in between the Sea and Portobello High Street (all buses take 15 mins to the City Centre). It is a family flat, I have only one son who is 8 years old called Leandro who is a very busy boy with lots of after school activities and he stays away with his dad twice a week during the week. His dad looks after him twice a week during the week at home, but they are super fun and quite busy with homework and projects. Our ideal flatmate is a professional person, who is a non-smoker, warm, kind, good at house keeping and who needs a lovely and cosy room to rest after work from Monday to Friday. I am a Pilates Professional and I run my own Pilates Studio which is also close to our flat (two blocks away). Therefore, if Pilates is your type of physical activity then there will be plenty Pilates sessions for you to choose from to take up after work during the week. I can provide fresh Bed Linnen (fortnightly) and fresh towels every week. All bills are included in the monthly rental fee. If you fit in with this type of accommodation and location then Leandro and I will be very much looking forward to welcoming you to Edinburgh/Portobello. Thank you very much. Sabrina & Leandro. :-) ",
#   'href': 'https://www.gumtree.com/p/property-to-rent/double-room-to-rent-monday-to-friday-in-portobello-suitable-for-one-person-only/1288367099',
#   'key_info': {'council_tax': None,
#    'date_available': '25/02/2018',
#    'deposit': None,
#    'epc': None,
#    'furnishing': None,
#    'letting_type': None,
#    'rent': 600.0,
#    'running_costs': {'council_tax': None,
#     'energy': None,
#     'insurrance': None,
#     'water': None}},
#   'source': 'gumtree',
#   'tags': None,
#   'title': 'Double Room to Rent Monday to Friday in Portobello suitable for One Person Only'},
#  {'address': {'area': None,
#    'city': None,
#    'latitude': 55.9358,
#    'longitude': -3.29826,
#    'postcode': None,
#    'street': None,
#    'tags': ['South Gyle', 'Edinburgh']},
#   'description': " Lovely bright double bedroom in South Gyle / Corstorphine with masses of storage space, freshly decorated and fully furnished with a new double bed and mattress.  Available from Tuesday 20 March onwards. Contact me for more info about potential moving dates!  £385 rent per month: Plus contribution to council tax and utilities (eg council tax £75; electricity & gas £20 each/month approx, depending on the season; wifi with superfast broadband £15/month). Free parking available.  To share with me! I'm a full time professional female, working locally. Non smoker, Independent, well used to convivial and considerate flatsharing. In my spare time I enjoy hill walking, keeping fit, etc. Ideally looking for a professional, working fully time, non smoker with a similar personality.  The house is really handily located - 2 mins from South Gyle station, with fast, frequent links to Haymarket and Edinburgh Waverley as well as to Edinburgh Airport and direct buses to Glasgow. It's only 10 mins from Corstorphine for more transport links as well as all your shops, cafes and nice places to eat - and a huge 24 hour Tesco. The new tram network stops at the Gyle Centre and at Bankhead, and is only a few minutes walk away too, as well as numerous bus stops nearby to connect right across the city - the 2, 12, 18, 21, 22, 35 and 70 are all within a few minutes' walk. Edinburgh Gateway, Edinburgh Park stations, and RBS Gogarburn are also all easily accessible.  It's a great location near The Gyle Shopping Centre, with David Lloyd Corstorphine Spa & Gym just across the park Energise Gym round the corner and Drumbrae Leisure Centre just over a mile away.  Quiet house, sunny and south facing, with amazing views to the Pentland Hills: Gas Central Heating and newly fitted bathroom including shower, lovely kitchen with electric hob and oven, microwave, fridge, freezer, brand new washing machine, tumble drier, etc.  Security deposit required. Sorry - no smokers, pets or DHSS. ",
#   'href': 'https://www.gumtree.com/p/property-to-rent/large-bright-double-room-with-lots-of-storage-in-shared-house/1288359845',
#   'key_info': {'council_tax': None,
#    'date_available': '20/03/2018',
#    'deposit': None,
#    'epc': None,
#    'furnishing': None,
#    'letting_type': None,
#    'rent': 385.0,
#    'running_costs': {'council_tax': None,
#     'energy': None,
#     'insurrance': None,
#     'water': None}},
#   'source': 'gumtree',
#   'tags': None,
#   'title': 'Large bright double room with lots of storage in shared house'},
#  {'address': {'area': None,
#    'city': None,
#    'latitude': 55.9497,
#    'longitude': -3.1356,
#    'postcode': None,
#    'street': None,
#    'tags': ['Willowbrae', 'Edinburgh']},
#   'description': ' Finesse Property Solutions are proud to present this 3 bedroom second floor flat. Which is entered by a well kept communal stair, the property compromises of a hall, spacious lounge, separate modern fitted kitchen and 2 double bedrooms 1 single.  Letting Information:  Date Available - 05/03/2018 Furnishing - Unfurnished Deposit - £850 Rent - £850 per month Letting Type - Long Term Council Tax Band - B EPC Rating - D Landlord Reg - 85296/230/12180  Key Features:  - Washing Machine- Fridge Freezer- Hob- Oven- Gas Central Heating - Double Glazing - Wooden Floors - Freshly Decorated throughout - Large Garden - On Street Parking  Location Information: Located East of the city, Northfield has a host of amenities with in a few minuets, well-served 3 local primary schools, including the acclaimed Royal High Primary School. Local amenities include Morison super market close by and a Tesco express very close to the property. A 10min bus ride brings you into the heart of the city and a short 5 min drive gives you access to the A!, city bypass, there is also a frequent and varied bus service in and out of the city.  ',
#   'href': 'https://www.gumtree.com/p/property-to-rent/3-bedroom-flat-north-field-grove-£850-per-month/1288220935',
#   'key_info': {'council_tax': None,
#    'date_available': '05/03/2018',
#    'deposit': None,
#    'epc': None,
#    'furnishing': None,
#    'letting_type': None,
#    'rent': 850.0,
#    'running_costs': {'council_tax': None,
#     'energy': None,
#     'insurrance': None,
#     'water': None}},
#   'source': 'gumtree',
#   'tags': None,
#   'title': '3 Bedroom flat, North Field Grove £850 per month'},
#  {'address': {'area': None,
#    'city': None,
#    'latitude': 55.9522,
#    'longitude': -3.22065,
#    'postcode': None,
#    'street': None,
#    'tags': ['Edinburgh City Centre', 'Edinburgh']},
#   'description': " 2 DOUBLE BEDROOM CONTEMPORARY MEWS.  Set within a modern development our contemporary Main door Mews is split over 2 floors & has 2 Double Bedrooms. It's located in the Dean Village. Only a few minutes walk from the City Centre & West End. 7 minutes walk to Charlotte Square & Princes Street. 10 mins walk along The Water of Leith to Stockbridge.  This was our home for 2 years & we loved living in the property. It is a contemporary Main door Mews property split over 2 floors. There is no one above you or below you and there are only 2 properties located on either side. Upon entering the front door there are 2 Double bedrooms (Master has a new Kingsize bed & Built in Wardrobes) & the 2nd bedroom has a double bed & a large wardrobe with plenty of drawers. There are also 2 cupboards in the hall - Lots of storage space for Golf Clubs or Pushchairs. The Bathroom has an Electric shower & the hot water for the bath runs of the Combi boiler.  The Stairs lead to the upper living level where you will find a comfortable lounge with 2 new sofas, A Smart TV preloaded with Netflix, side tables, and a dining area with dining table & 4 new chairs. There is also a small office area with built in desk & storage & a new office chair.  The living area leads into the Kitchen which is fitted with Integrated Neff Appliances (Dishwasher, Washer/Drier, Fridge Freezer, Electric Oven & Gas hob) We have provided cutlery, crockery and glasses, and pots / pans.  Our property benefits from gas central heating, double glazing, integrated appliances, excellent standard of decor and furnishings throughout, permit parking, underground bike storage. We have recently installed new engineered oak flooring and painted the apartment completely.  Please email me for more info or to arrange a viewing.  £300 per week to be paid monthly. Minimum 6 months lease.  Deposit & 1 months rent payable up front. Non smoking property. Tenant responsible for Council tax & other bills.  EPC band C Landlord Registration Number 0019442  ",
#   'href': 'https://www.gumtree.com/p/property-to-rent/main-door-mews-west-end-dean-village-2-double-bedrooms-7-mins-walk-to-city-centre-£1300-per-month/1288329697',
#   'key_info': {'council_tax': None,
#    'date_available': '26/02/2018',
#    'deposit': None,
#    'epc': None,
#    'furnishing': None,
#    'letting_type': None,
#    'rent': 1300.0,
#    'running_costs': {'council_tax': None,
#     'energy': None,
#     'insurrance': None,
#     'water': None}},
#   'source': 'gumtree',
#   'tags': None,
#   'title': 'MAIN DOOR MEWS WEST END (DEAN VILLAGE) 2 DOUBLE BEDROOMS 7 MINS WALK TO CITY CENTRE £1300 Per Month'},
#  {'address': {'area': None,
#    'city': None,
#    'latitude': None,
#    'longitude': None,
#    'postcode': None,
#    'street': None,
#    'tags': ['Edinburgh']},
#   'description': ' Furnished two double bedroom flat for immediate rent in Morningside. The flat is on the 2nd floor, has secure entry and is only a short walk into Morningside with great local amenities and beside bus stop numbers 23 and 38.  The flat is fully furnished and comprises of an entrance hallway, bright south facing lounge, kitchen, two double bedrooms and bathroom with shower. The flat has double glazed windows, electric heating, shower, smoke detector, with shared garden and free off street parking. Council Tax Band - D  Sorry, no students, no smoking, no DSS or pets.  Landlord registration: 632911/230/05121 ',
#   'href': 'https://www.gumtree.com/p/property-to-rent/2-bedroom-flat-for-immediate-rent-in-morningside/1288328613',
#   'key_info': {'council_tax': None,
#    'date_available': '25/02/2018',
#    'deposit': None,
#    'epc': None,
#    'furnishing': None,
#    'letting_type': None,
#    'rent': 795.0,
#    'running_costs': {'council_tax': None,
#     'energy': None,
#     'insurrance': None,
#     'water': None}},
#   'source': 'gumtree',
#   'tags': None,
#   'title': '2 bedroom flat for immediate rent in Morningside'},
#  {'address': {'area': None,
#    'city': None,
#    'latitude': 55.9359,
#    'longitude': -3.30794,
#    'postcode': None,
#    'street': None,
#    'tags': ['South Gyle', 'Edinburgh']},
#   'description': ' A family home located in a quiet cul-de-sac at Gogarloch syke with spacious space and offers a comfortable living environment with excellent local amenities, schooling and transport links.  5 minutes walk to the Gyle Shopping Centre and Edinburgh Business Park. Property also within close proximity to city bypass, South Gyle train station, tram and bus routes into Edinburgh City Centre and airport.  Property comprises of a bright living rooms and a modern dining kitchen leading to a second living room with access to the garden. Upstairs there are two double bedrooms, one single bedroom and a modern fitted bathroom.  The property benefits from double glazing and gas central heating. There is a private enclosed back garden with a large shed to the rear and a front garden with private parking space.  Deposit £1200 Working professionals only, Sorry no DSS Landlord Reg No. 334701/230/25271 ',
#   'href': 'https://www.gumtree.com/p/property-to-rent/unfurnished-3-bed-end-terraced-house-gogarloch-syke-gyle-edinburgh-eh12-9jd/1288320033',
#   'key_info': {'council_tax': None,
#    'date_available': '31/03/2018',
#    'deposit': None,
#    'epc': None,
#    'furnishing': None,
#    'letting_type': None,
#    'rent': 995.0,
#    'running_costs': {'council_tax': None,
#     'energy': None,
#     'insurrance': None,
#     'water': None}},
#   'source': 'gumtree',
#   'tags': None,
#   'title': 'unfurnished 3 bed end-terraced house Gogarloch Syke, Gyle, Edinburgh EH12 9JD'},
#  {'address': {'area': None,
#    'city': None,
#    'latitude': None,
#    'longitude': None,
#    'postcode': None,
#    'street': None,
#    'tags': ['Fettes', 'Edinburgh']},
#   'description': ' I am looking for a two bedroom Unfurnished flat/house ideally no more than £850 per month. I would preferably like to stay close to the city centre as I work in town but would consider further options.  I have currently been renting a property the last two years through an agency but the landlord would now like to sell. My landlord is happy for me to leave earlier than the two month notice so I can move in somewhere immediately if needed.I have been a very good tenant over the two years and can provide great references. I am also a non smoker and work full time.  Please email me if you have a property available.  Thank you   ',
#   'href': 'https://www.gumtree.com/p/property-to-rent/seeking-unfurnished-long-term-let-2-bedroom-flat-house-asap/1288304702',
#   'key_info': {'council_tax': None,
#    'date_available': '24/02/2018',
#    'deposit': None,
#    'epc': None,
#    'furnishing': None,
#    'letting_type': None,
#    'rent': 800.0,
#    'running_costs': {'council_tax': None,
#     'energy': None,
#     'insurrance': None,
#     'water': None}},
#   'source': 'gumtree',
#   'tags': None,
#   'title': 'Seeking Unfurnished long term let 2 bedroom flat/house asap'},
#  {'address': {'area': None,
#    'city': None,
#    'latitude': 55.9333,
#    'longitude': -3.2139,
#    'postcode': None,
#    'street': None,
#    'tags': ['Bruntsfield', 'Edinburgh']},
#   'description': ' Accommodation for overseas students for one semester in central edinburgh perfect for heriott watt, napier and edinburgh universities ',
#   'href': 'https://www.gumtree.com/p/property-to-rent/university-accommodation-for-one-semester-international-students/1270612472',
#   'key_info': {'council_tax': None,
#    'date_available': '26/02/2018',
#    'deposit': None,
#    'epc': None,
#    'furnishing': None,
#    'letting_type': None,
#    'rent': 800.0,
#    'running_costs': {'council_tax': None,
#     'energy': None,
#     'insurrance': None,
#     'water': None}},
#   'source': 'gumtree',
#   'tags': None,
#   'title': 'University accommodation for one semester international students'},
#  {'address': {'area': None,
#    'city': None,
#    'latitude': 55.93823,
#    'longitude': -3.21583,
#    'postcode': None,
#    'street': None,
#    'tags': ['Polwarth', 'Edinburgh']},
#   'description': ' STUDENT LET Huge 3 storey townhouse in bruntsfield. 9 bedrooms, 7 bathrooms, HMO for 18 Beautiful large house with 9 bedrooms, 5 of which are ensuite and the other 4 share two bathrooms. Most rooms have double beds or two single beds. There is a large dining/ lounge room and large kitchen. Rooms vary slightly on price due to size but start from £550pm upto £700pm All utility bills, TV license and superfast fibre optic virgin broadband also included. Currently trading as a guesthouse but being changed to offer student accommodation from 2 September 2018 A large group applying together preferred. Well respected agency full landlord registration and deposit scheme no upfront tenant fees    ',
#   'href': 'https://www.gumtree.com/p/property-to-rent/huge-townhouse-in-bruntsfield-9-dble-bdrms-7-bthrms-lounge.-kitchen-hmo-suit-big-group-students/1282040457',
#   'key_info': {'council_tax': None,
#    'date_available': '03/09/2018',
#    'deposit': None,
#    'epc': None,
#    'furnishing': None,
#    'letting_type': None,
#    'rent': 550.0,
#    'running_costs': {'council_tax': None,
#     'energy': None,
#     'insurrance': None,
#     'water': None}},
#   'source': 'gumtree',
#   'tags': None,
#   'title': 'Huge townhouse in bruntsfield - 9 dble bdrms, 7 bthrms, lounge. kitchen HMO suit big group students'},
#  {'address': {'area': None,
#    'city': None,
#    'latitude': 55.9471,
#    'longitude': -3.21578,
#    'postcode': None,
#    'street': None,
#    'tags': ['Haymarket', 'Edinburgh']},
#   'description': " variety of student flats from 2 bedroom to 7 bedrooms. * NOTE- We don't have any 1 bed flats left, We have 2 four bed available in Gorgie and Merchiston, a 2/3 bed flat in morningside, a 5/6 bed flat in haymarket and a 7 bed flat in haymarket. some available now for one term/semester, others from June and most from September. please send your requirements in terms of number of bedrooms and desired location and entry date and we will send you details of what is still available full landlord registration from long running and respected agency  ",
#   'href': 'https://www.gumtree.com/p/property-to-rent/student-flats-available-september-2018/1279397096',
#   'key_info': {'council_tax': None,
#    'date_available': '19/02/2018',
#    'deposit': None,
#    'epc': None,
#    'furnishing': None,
#    'letting_type': None,
#    'rent': 750.0,
#    'running_costs': {'council_tax': None,
#     'energy': None,
#     'insurrance': None,
#     'water': None}},
#   'source': 'gumtree',
#   'tags': None,
#   'title': 'STUDENT FLATS AVAILABLE SEPTEMBER 2018'},
#  {'address': {'area': None,
#    'city': None,
#    'latitude': 55.9274,
#    'longitude': -3.2103,
#    'postcode': None,
#    'street': None,
#    'tags': ['Morningside', 'Edinburgh']},
#   'description': ' Beautiful 2/3 bedroom flat available now. currently has large lounge which is also used as bedroom, two double bedrooms, kitchen, bathroom. Plus large private gardens so great for dog or cat owners. It is ground floor and just seconds walk to morningside road. Also just being renovated this week so will have a brand new bathroom and decoration in next week or two. Landlord registration number- 432628/230/16251 no HMO so only couples or family only if over 2 people £1500 per month including bills (not council tax but its free for students) No agency fees A months rent deposit required - £1500 ',
#   'href': 'https://www.gumtree.com/p/property-to-rent/large-bright-2-3-double-bedroom-flat-in-morningside.-private-gardens-quiet-and-perfect-location/1280079273',
#   'key_info': {'council_tax': None,
#    'date_available': '26/02/2018',
#    'deposit': None,
#    'epc': None,
#    'furnishing': None,
#    'letting_type': None,
#    'rent': 1500.0,
#    'running_costs': {'council_tax': None,
#     'energy': None,
#     'insurrance': None,
#     'water': None}},
#   'source': 'gumtree',
#   'tags': None,
#   'title': 'Large bright 2/3 double Bedroom flat in Morningside. Private gardens, quiet and perfect location'},
#  {'address': {'area': None,
#    'city': None,
#    'latitude': 55.9367,
#    'longitude': -3.24264,
#    'postcode': None,
#    'street': None,
#    'tags': ['Gorgie', 'Edinburgh']},
#   'description': ' this is a great 4 bedroomed flat now available for most of july and all of august and onwards. sleeps 8-10 easily. 3 bedrooms, fully equipped large kitchen, very large lounge dining, balcony, free parking, play park and a million buses pass close by so very quick to centre. there are no tenant fees at all!! ',
#   'href': 'https://www.gumtree.com/p/property-to-rent/festival-fringe-let-in-gorgie-just-10-min-bus-ride-to-centre/1225613462',
#   'key_info': {'council_tax': None,
#    'date_available': '01/08/2018',
#    'deposit': None,
#    'epc': None,
#    'furnishing': None,
#    'letting_type': None,
#    'rent': 1500.0,
#    'running_costs': {'council_tax': None,
#     'energy': None,
#     'insurrance': None,
#     'water': None}},
#   'source': 'gumtree',
#   'tags': None,
#   'title': 'festival fringe let in gorgie just 10 min bus ride to centre'},
#  {'address': {'area': None,
#    'city': None,
#    'latitude': None,
#    'longitude': None,
#    'postcode': None,
#    'street': None,
#    'tags': ['Sighthill', 'Edinburgh']},
#   'description': ' Student let- fully renovated double upper 4 dble bed HMO flat in sighthill close to herriott watt university and really close to napier sighthill campus- 5 mins walk Just being renovated now and will consist of 4 large double bedrooms, two bathrooms, lounge, brilliant new kitchen, large gardens all bedrooms will have brand new furniture, double beds, desks etc rent is £1600pm and this includes all bills and superfast fibre optic broadband/ WIFI Flat ready from 1st September. No tenant fees and well established agency landlord registration- ',
#   'href': 'https://www.gumtree.com/p/property-to-rent/students-fully-renovated-4-bed-hmo-in-sighthill-close-to-herriott-watt.-£1600-includes-all-bills/1283986583',
#   'key_info': {'council_tax': None,
#    'date_available': '01/09/2018',
#    'deposit': None,
#    'epc': None,
#    'furnishing': None,
#    'letting_type': None,
#    'rent': 1600.0,
#    'running_costs': {'council_tax': None,
#     'energy': None,
#     'insurrance': None,
#     'water': None}},
#   'source': 'gumtree',
#   'tags': None,
#   'title': 'Students fully renovated 4 bed HMO in sighthill close to herriott watt. £1600 includes all bills'}]
